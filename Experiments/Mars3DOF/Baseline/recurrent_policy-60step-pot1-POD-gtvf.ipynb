# %% [markdown]
# # Test RNN Policy  with Engine Failure

# %%
import numpy as np
import os,sys



sys.path.append('../../../RL_lib/Agents/PPO')
sys.path.append('../../../RL_lib/Utils')
sys.path.append('../../../Mars3dof_env')

# %load_ext autoreload
# %load_ext autoreload
# %autoreload 2
# %matplotlib nbagg
import os
print(os.getcwd())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/briangaudet/Study/Subjects/MachineLearning/Projects/RL_Meta-Learning-master/Experiments/Mars3DOF/Baseline

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:1000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:1000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %% [markdown]
# # Optimize Policy

# %%
from env import Env
import env_utils as envu
from dynamics_model import Dynamics_model
from lander_model import Lander_model
from ic_gen2 import Landing_icgen
import rl_utils

from arch_policy_gtvf import Arch

from policy import Policy
from value_function import Value_function

import policy_nets as policy_nets
import valfunc_nets as valfunc_nets

from agent import Agent


import torch.nn as nn

from flat_constraint import Flat_constraint
from glideslope_constraint import Glideslope_constraint
from reward_terminal_mdr import Reward


logger = rl_utils.Logger()
dynamics_model = Dynamics_model()
lander_model = Lander_model(apf_tau1=20,apf_tau2=100,apf_vf1=-2,apf_vf2=-1,apf_v0=70,apf_atarg=15)
lander_model.get_state_agent = lander_model.get_state_agent_po_delta
lander_model.apf_pot = lander_model.apf_pot2
obs_dim = 6
gt_dim = 5
act_dim = 3
recurrent_steps = 60

reward_object = Reward()

glideslope_constraint = Glideslope_constraint(gs_limit=-1.0)
shape_constraint = Flat_constraint()
env = Env(lander_model,dynamics_model,logger,
          reward_object=reward_object,
          glideslope_constraint=glideslope_constraint,
          shape_constraint=shape_constraint,
          tf_limit=100.0,print_every=10)

env.ic_gen = Landing_icgen(mass_uncertainty=0.05, 
                           g_uncertainty=(0.05,0.05),
                           adjust_apf_v0=True,
                          downrange = (0,2000 , -70, -10), 
                           crossrange = (-1000,1000 , -30,30),  
                           altitude = (2300,2400,-90,-70))
env.ic_gen.show()

arch = Arch()

policy = Policy(policy_nets.GRU(obs_dim, act_dim, recurrent_steps=recurrent_steps), shuffle=False,
                kl_targ=0.001,epochs=20, beta=0.1, servo_kl=True, max_grad_norm=30,
                init_func=rl_utils.xn_init)
value_function = Value_function(valfunc_nets.GRU(gt_dim, recurrent_steps=recurrent_steps), 
                                shuffle=False, batch_size=9999999, max_grad_norm=30,obs_key='muxed_observes')

agent = Agent(arch, policy, value_function, None, env, logger,
              policy_episodes=30, policy_steps=3000, gamma1=0.95, gamma2=0.995, lam=0.98, 
              recurrent_steps=recurrent_steps, monitor=env.rl_stats)


agent.train(90000)
# Out:
# 3-dof dynamics model
# lander model apf
# queue fixed
# Flat Constraint
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# Lander Env
# Landing_icgen:
#     nominal_g                   :  -3.7114
#     downrange                   :  (0, 2000, -70, -10)
#     crossrange                  :  (-1000, 1000, -30, 30)
#     altitude                    :  (2300, 2400, -90, -70)
#     adjust_apf_v0               :  True
# Policy with vectorized sample
# 	xn_init: layer  Linear(in_features=6, out_features=60, bias=True)
# 	xn_init: layer  GRUCell(60, 42)
# 	xn_init: layer  Linear(in_features=42, out_features=30, bias=True)
# 	xn_init: layer  Linear(in_features=30, out_features=3, bias=True)
# Policy: recurrent steps > 1, disabling shuffle
# [[-1.]
#  [ 0.]
#  [ 1.]]
# 	Test Mode:          False
# 	Clip Param:         0.1
# 	Shuffle :           False
# 	Max Grad Norm:      30
# 	Recurrent Steps:    60
# 	Rollout Limit:      1
# Value Funtion
# 	xn_init: layer  Linear(in_features=5, out_features=50, bias=True)
# 	xn_init: layer  GRUCell(50, 15)
# 	xn_init: layer  Linear(in_features=15, out_features=5, bias=True)
# 	xn_init: layer  Linear(in_features=5, out_features=1, bias=True)
# Value Function: recurrent steps > 1, disabling shuffle and batching
# 	Clip Range:         0.5
# 	Shuffle :           False
# 	Batch Size :        9999999
# 	Max Grad Norm:      30
# 	Recurrent Steps:    60
# 	Rollout Limit:      1
# Agent
# *** SCALER WARMUP COMPLETE ***
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0956   0.0361   0.1889   0.1889   0.0956   0.0361
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.7443   0.6515   2.0347   2.0347   0.7443   0.6515
# Update Cnt = 0    ET =     14.2   Stats:  Mean, Std, Min, Max
# r_f      |   365.6    71.6    -3.7 |   623.8   715.1     2.3 |  -921.5 -1313.7    -8.0 |  1349.9  1150.5    -0.0
# v_f      |  -41.38    4.53 -153.97 |   14.80   23.13    9.49 |  -70.30  -38.37 -177.43 |  -13.32   54.39 -134.29
# vr_f     |     3.7 |     1.6 |     2.0 |     8.9
# r_i      |  1094.1   108.7  2350.7 |   538.3   598.9    28.6 |    70.9  -947.0  2302.1 |  1899.8   977.1  2397.3
# v_i      |  -36.58    3.05  -79.62 |   16.07   18.03    6.21 |  -69.40  -26.33  -89.99 |  -10.18   29.03  -70.05
# norm_rf  |   952.0 |   364.8 |   360.8 |  1648.9
# norm_vf  |  161.79 |   10.34 |  142.30 |  180.10
# thrust   |    -418      96     235 |    7299    7637    7295 |  -14994  -14994  -14970 |   14983   14980   14995
# norm_thrust |   12393 |    3387 |    2000 |   15000
# fuel     |     125 |       8 |     114 |     142
# rewards  |  -98.05 |    7.44 | -120.94 |  -84.07
# fuel_rewards |   -4.32 |    0.26 |   -4.87 |   -3.90
# glideslope_rewards |    0.00 |    0.00 |    0.00 |    0.00
# glideslope_penalty |    0.00 |    0.00 |    0.00 |    0.00
# glideslope |    2.09 |    0.70 |    1.16 |    3.68
# sc_rewards |    0.00 |    0.00 |    0.00 |    0.00
# sc_penalty |    0.00 |    0.00 |    0.00 |    0.00
# sc_margin |  100.00 |    0.00 |  100.00 |  100.00
# range_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_margin |  947.02 |  364.77 |  355.79 | 1643.90
# tracking_rewards |  -93.74 |    7.46 | -116.56 |  -79.73
# steps    |     104 |       7 |      91 |     115
# ***** Episode 0, Mean R = -98.1  Std R = 7.4  Min R = -120.9
# Beta: 0.1
# ExplainedVarNew: -0.34
# ExplainedVarOld: -0.555
# KL: 0.00153
# PolicyEntropy: 2.74
# PolicyLoss: -0.00447
# Steps: 3.22e+03
# TotalSteps: 3.22e+03
# ValFuncLoss: 0.239
# Variance: 0.603
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1419   0.0464   0.2058   0.2058   0.1419   0.0464
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1084   0.0683   0.3016   2.0347   0.7443   0.6515
# ***** Episode 31, Mean R = -97.8  Std R = 8.7  Min R = -120.4
# Beta: 0.1
# ExplainedVarNew: 0.147
# ExplainedVarOld: -0.286
# KL: 0.00127
# PolicyEntropy: 2.72
# PolicyLoss: -0.00361
# Steps: 3.27e+03
# TotalSteps: 6.49e+03
# ValFuncLoss: 0.051
# Variance: 0.6
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1415   0.0505   0.2457   0.2457   0.1419   0.0505
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0493   0.0141   0.0709   2.0347   0.7443   0.6515
# ***** Episode 62, Mean R = -99.4  Std R = 9.8  Min R = -123.4
# Beta: 0.1
# ExplainedVarNew: 0.351
# ExplainedVarOld: 0.232
# KL: 0.000961
# PolicyEntropy: 2.71
# PolicyLoss: -0.00318
# Steps: 3.27e+03
# TotalSteps: 9.76e+03
# ValFuncLoss: 0.0472
# Variance: 0.598
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1635   0.0427   0.2305   0.2457   0.1635   0.0505
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0396   0.0126   0.0688   2.0347   0.7443   0.6515
# ***** Episode 93, Mean R = -96.7  Std R = 7.2  Min R = -116.1
# Beta: 0.1
# ExplainedVarNew: 0.658
# ExplainedVarOld: 0.519
# KL: 0.00163
# PolicyEntropy: 2.71
# PolicyLoss: -0.00336
# Steps: 3.22e+03
# TotalSteps: 1.3e+04
# ValFuncLoss: 0.0286
# Variance: 0.6
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1907   0.0578   0.2644   0.2644   0.1907   0.0578
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0367   0.0159   0.0719   2.0347   0.7443   0.6515
# ***** Episode 124, Mean R = -100.6  Std R = 10.3  Min R = -128.9
# Beta: 0.1
# ExplainedVarNew: 0.77
# ExplainedVarOld: 0.761
# KL: 0.0016
# PolicyEntropy: 2.7
# PolicyLoss: -0.00386
# Steps: 3.24e+03
# TotalSteps: 1.62e+04
# ValFuncLoss: 0.0184
# Variance: 0.601
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1662   0.0641   0.2605   0.2644   0.1907   0.0641
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0130   0.0053   0.0262   2.0347   0.7443   0.6515
# ***** Episode 155, Mean R = -102.3  Std R = 10.7  Min R = -129.3
# Beta: 0.0667
# ExplainedVarNew: 0.868
# ExplainedVarOld: 0.86
# KL: 0.00218
# PolicyEntropy: 2.7
# PolicyLoss: -0.00395
# Steps: 3.29e+03
# TotalSteps: 1.95e+04
# ValFuncLoss: 0.00857
# Variance: 0.6
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2034   0.0720   0.3238   0.3238   0.2034   0.0720
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0229   0.0142   0.0601   2.0347   0.7443   0.6515
# ***** Episode 186, Mean R = -98.4  Std R = 9.5  Min R = -120.4
# Beta: 0.0667
# ExplainedVarNew: 0.878
# ExplainedVarOld: 0.868
# KL: 0.000901
# PolicyEntropy: 2.69
# PolicyLoss: -0.00364
# Steps: 3.29e+03
# TotalSteps: 2.28e+04
# ValFuncLoss: 0.00614
# Variance: 0.6
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1750   0.0658   0.2678   0.3238   0.2034   0.0720
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0372   0.0233   0.0838   2.0347   0.7443   0.6515
# ***** Episode 217, Mean R = -93.7  Std R = 8.3  Min R = -125.8
# Beta: 0.0667
# ExplainedVarNew: 0.907
# ExplainedVarOld: 0.889
# KL: 0.000721
# PolicyEntropy: 2.69
# PolicyLoss: -0.00301
# Steps: 3.36e+03
# TotalSteps: 2.62e+04
# ValFuncLoss: 0.00487
# Variance: 0.601
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2059   0.0852   0.3331   0.3331   0.2059   0.0852
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0144   0.0057   0.0226   2.0347   0.7443   0.6515
# ***** Episode 248, Mean R = -94.5  Std R = 6.6  Min R = -116.7
# Beta: 0.0667
# ExplainedVarNew: 0.932
# ExplainedVarOld: 0.927
# KL: 0.000748
# PolicyEntropy: 2.69
# PolicyLoss: -0.00325
# Steps: 3.42e+03
# TotalSteps: 2.96e+04
# ValFuncLoss: 0.00292
# Variance: 0.599
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1827   0.0803   0.3179   0.3331   0.2059   0.0852
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0150   0.0069   0.0313   2.0347   0.7443   0.6515
# ***** Episode 279, Mean R = -97.9  Std R = 12.6  Min R = -135.9
# Beta: 0.0667
# ExplainedVarNew: 0.872
# ExplainedVarOld: 0.849
# KL: 0.00103
# PolicyEntropy: 2.69
# PolicyLoss: -0.00369
# Steps: 3.43e+03
# TotalSteps: 3.3e+04
# ValFuncLoss: 0.00663
# Variance: 0.599
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2597   0.1207   0.4600   0.4600   0.2597   0.1207
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0127   0.0051   0.0228   2.0347   0.7443   0.6515
# Update Cnt = 10    ET =     92.0   Stats:  Mean, Std, Min, Max
# r_f      |   259.5   -73.4    -3.7 |   689.8   629.5     2.1 | -1376.8 -1710.1    -8.8 |  1837.8  1475.9    -0.0
# v_f      |  -41.88    1.32 -147.12 |   15.05   30.11   10.80 |  -81.64  -79.72 -181.24 |    2.46   85.20 -112.77
# vr_f     |     3.2 |     1.2 |     1.6 |     8.6
# r_i      |  1007.6    42.8  2347.6 |   578.2   589.5    29.3 |     2.8  -999.5  2300.2 |  1993.5   997.4  2399.5
# v_i      |  -38.58    0.27  -79.70 |   17.11   16.81    5.75 |  -69.98  -29.76  -89.94 |  -10.22   29.69  -70.14
# norm_rf  |   871.3 |   430.8 |    66.5 |  2353.1
# norm_vf  |  156.58 |   11.53 |  122.97 |  190.63
# thrust   |    -243      76    1082 |    7342    7593    7173 |  -14997  -14996  -14999 |   14995   14997   15000
# norm_thrust |   12356 |    3402 |    2000 |   15000
# fuel     |     129 |      10 |     103 |     161
# rewards  |  -97.57 |    9.75 | -135.85 |  -81.45
# fuel_rewards |   -4.44 |    0.34 |   -5.52 |   -3.53
# glideslope_rewards |    0.00 |    0.00 |    0.00 |    0.00
# glideslope_penalty |    0.00 |    0.00 |    0.00 |    0.00
# glideslope |    2.08 |    0.83 |    1.01 |    5.40
# sc_rewards |    0.00 |    0.00 |    0.00 |    0.00
# sc_penalty |    0.00 |    0.00 |    0.00 |    0.00
# sc_margin |  100.00 |    0.00 |  100.00 |  100.00
# range_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_margin |  868.05 |  427.84 |  132.30 | 2348.07
# tracking_rewards |  -93.13 |    9.75 | -131.41 |  -76.91
# steps    |     107 |       7 |      88 |     132
# ***** Episode 310, Mean R = -94.5  Std R = 8.7  Min R = -115.5
# Beta: 0.0667
# ExplainedVarNew: 0.872
# ExplainedVarOld: 0.845
# KL: 0.00119
# PolicyEntropy: 2.69
# PolicyLoss: -0.00415
# Steps: 3.42e+03
# TotalSteps: 3.64e+04
# ValFuncLoss: 0.00606
# Variance: 0.598
# lr_multiplier: 1
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2183   0.1008   0.4062   0.4600   0.2597   0.1207
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0102   0.0062   0.0270   2.0347   0.7443   0.6515
# ***** Episode 341, Mean R = -93.7  Std R = 6.7  Min R = -106.8
# Beta: 0.0667
# ExplainedVarNew: 0.934
# ExplainedVarOld: 0.926
# KL: 0.0012
# PolicyEntropy: 2.67
# PolicyLoss: -0.00408
# Steps: 3.49e+03
# TotalSteps: 3.99e+04
# ValFuncLoss: 0.00311
# Variance: 0.596
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1969   0.0639   0.3150   0.4600   0.2597   0.1207
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0113   0.0059   0.0247   2.0347   0.7443   0.6515
# ***** Episode 372, Mean R = -96.2  Std R = 8.2  Min R = -120.3
# Beta: 0.0667
# ExplainedVarNew: 0.921
# ExplainedVarOld: 0.908
# KL: 0.00132
# PolicyEntropy: 2.66
# PolicyLoss: -0.0033
# Steps: 3.44e+03
# TotalSteps: 4.34e+04
# ValFuncLoss: 0.00401
# Variance: 0.594
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2210   0.0890   0.3709   0.4600   0.2597   0.1207
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0109   0.0048   0.0219   2.0347   0.7443   0.6515
# ***** Episode 403, Mean R = -97.8  Std R = 15.1  Min R = -136.4
# Beta: 0.0667
# ExplainedVarNew: 0.864
# ExplainedVarOld: 0.842
# KL: 0.00114
# PolicyEntropy: 2.66
# PolicyLoss: -0.00302
# Steps: 3.53e+03
# TotalSteps: 4.69e+04
# ValFuncLoss: 0.00871
# Variance: 0.595
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2783   0.1151   0.4386   0.4600   0.2783   0.1207
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0120   0.0063   0.0267   2.0347   0.7443   0.6515
# ***** Episode 434, Mean R = -94.6  Std R = 14.4  Min R = -147.9
# Beta: 0.0667
# ExplainedVarNew: 0.901
# ExplainedVarOld: 0.895
# KL: 0.00071
# PolicyEntropy: 2.66
# PolicyLoss: -0.00367
# Steps: 3.59e+03
# TotalSteps: 5.05e+04
# ValFuncLoss: 0.00646
# Variance: 0.596
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1787   0.0802   0.3029   0.4600   0.2783   0.1207
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0130   0.0063   0.0267   2.0347   0.7443   0.6515
# ***** Episode 465, Mean R = -95.8  Std R = 11.7  Min R = -129.7
# Beta: 0.0667
# ExplainedVarNew: 0.848
# ExplainedVarOld: 0.788
# KL: 0.000787
# PolicyEntropy: 2.66
# PolicyLoss: -0.00291
# Steps: 3.6e+03
# TotalSteps: 5.41e+04
# ValFuncLoss: 0.00747
# Variance: 0.594
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2275   0.0799   0.3573   0.4600   0.2783   0.1207
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0129   0.0068   0.0295   2.0347   0.7443   0.6515
# ***** Episode 496, Mean R = -94.0  Std R = 9.8  Min R = -121.5
# Beta: 0.0667
# ExplainedVarNew: 0.897
# ExplainedVarOld: 0.886
# KL: 0.000814
# PolicyEntropy: 2.66
# PolicyLoss: -0.00379
# Steps: 3.68e+03
# TotalSteps: 5.78e+04
# ValFuncLoss: 0.00612
# Variance: 0.594
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2587   0.1071   0.4298   0.4600   0.2783   0.1207
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0163   0.0090   0.0373   2.0347   0.7443   0.6515
# ***** Episode 527, Mean R = -90.8  Std R = 8.7  Min R = -119.9
# Beta: 0.0667
# ExplainedVarNew: 0.926
# ExplainedVarOld: 0.92
# KL: 0.00114
# PolicyEntropy: 2.65
# PolicyLoss: -0.00376
# Steps: 3.68e+03
# TotalSteps: 6.14e+04
# ValFuncLoss: 0.00552
# Variance: 0.592
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2602   0.1159   0.4465   0.4600   0.2783   0.1207
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0147   0.0082   0.0316   2.0347   0.7443   0.6515
# ***** Episode 558, Mean R = -94.3  Std R = 11.5  Min R = -120.9
# Beta: 0.0667
# ExplainedVarNew: 0.915
# ExplainedVarOld: 0.901
# KL: 0.000966
# PolicyEntropy: 2.64
# PolicyLoss: -0.00407
# Steps: 3.8e+03
# TotalSteps: 6.52e+04
# ValFuncLoss: 0.00722
# Variance: 0.591
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1715   0.0597   0.2691   0.4600   0.2783   0.1207
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0081   0.0023   0.0130   2.0347   0.7443   0.6515
# ***** Episode 589, Mean R = -92.1  Std R = 11.4  Min R = -124.1
# Beta: 0.0667
# ExplainedVarNew: 0.898
# ExplainedVarOld: 0.879
# KL: 0.000862
# PolicyEntropy: 2.63
# PolicyLoss: -0.00249
# Steps: 3.94e+03
# TotalSteps: 6.92e+04
# ValFuncLoss: 0.00716
# Variance: 0.589
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3011   0.1223   0.5239   0.5239   0.3011   0.1223
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0106   0.0051   0.0233   2.0347   0.7443   0.6515
# Update Cnt = 20    ET =    115.8   Stats:  Mean, Std, Min, Max
# r_f      |   227.3   -90.6    -3.2 |   663.5   602.5     2.0 | -1189.7 -1632.7    -7.5 |  1759.5  1391.9    -0.0
# v_f      |  -33.11    6.42 -129.51 |   14.60   25.37   11.39 |  -70.44  -64.13 -154.74 |    1.71   72.30  -94.97
# vr_f     |     3.7 |     2.2 |     1.5 |    17.7
# r_i      |   955.7     3.8  2350.3 |   584.3   594.0    28.6 |     9.4  -997.0  2300.1 |  1993.3   996.4  2399.3
# v_i      |  -39.13   -0.57  -79.80 |   18.00   16.86    5.80 |  -69.93  -29.97  -90.00 |  -10.03   29.86  -70.03
# norm_rf  |   827.9 |   421.7 |    54.1 |  2110.9
# norm_vf  |  136.88 |   12.68 |   97.67 |  168.52
# thrust   |     533     550    3058 |    7200    7480    6929 |  -14988  -14999  -14993 |   14999   14999   15000
# norm_thrust |   12427 |    3363 |    2000 |   15000
# fuel     |     143 |      13 |     108 |     204
# rewards  |  -94.04 |   11.55 | -147.90 |  -72.16
# fuel_rewards |   -4.91 |    0.46 |   -7.03 |   -3.72
# glideslope_rewards |    0.00 |    0.00 |    0.00 |    0.00
# glideslope_penalty |    0.00 |    0.00 |    0.00 |    0.00
# glideslope |    2.06 |    0.83 |    0.99 |    5.08
# sc_rewards |    0.00 |    0.00 |    0.00 |    0.00
# sc_penalty |    0.00 |    0.00 |    0.00 |    0.00
# sc_margin |  100.00 |    0.00 |  100.00 |  100.00
# range_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_margin |  823.88 |  419.95 |  117.55 | 2105.91
# tracking_rewards |  -89.13 |   11.61 | -142.33 |  -66.10
# steps    |     118 |      10 |      97 |     160
# ***** Episode 620, Mean R = -91.0  Std R = 13.1  Min R = -137.4
# Beta: 0.0667
# ExplainedVarNew: 0.955
# ExplainedVarOld: 0.945
# KL: 0.00102
# PolicyEntropy: 2.62
# PolicyLoss: -0.00463
# Steps: 3.77e+03
# TotalSteps: 7.3e+04
# ValFuncLoss: 0.00482
# Variance: 0.589
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2811   0.1157   0.4712   0.5239   0.3011   0.1223
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0086   0.0036   0.0195   2.0347   0.7443   0.6515
# ***** Episode 651, Mean R = -91.6  Std R = 12.5  Min R = -126.5
# Beta: 0.0667
# ExplainedVarNew: 0.945
# ExplainedVarOld: 0.927
# KL: 0.00115
# PolicyEntropy: 2.62
# PolicyLoss: -0.00421
# Steps: 4.07e+03
# TotalSteps: 7.7e+04
# ValFuncLoss: 0.00409
# Variance: 0.591
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2571   0.1151   0.4403   0.5239   0.3011   0.1223
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0125   0.0040   0.0218   2.0347   0.7443   0.6515
# ***** Episode 682, Mean R = -90.0  Std R = 11.6  Min R = -127.9
# Beta: 0.0667
# ExplainedVarNew: 0.903
# ExplainedVarOld: 0.887
# KL: 0.00112
# PolicyEntropy: 2.61
# PolicyLoss: -0.00315
# Steps: 4.04e+03
# TotalSteps: 8.11e+04
# ValFuncLoss: 0.00433
# Variance: 0.59
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2683   0.1315   0.4543   0.5239   0.3011   0.1315
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0153   0.0070   0.0321   2.0347   0.7443   0.6515
# ***** Episode 713, Mean R = -91.5  Std R = 12.3  Min R = -130.2
# Beta: 0.0667
# ExplainedVarNew: 0.938
# ExplainedVarOld: 0.932
# KL: 0.000913
# PolicyEntropy: 2.6
# PolicyLoss: -0.00385
# Steps: 4.06e+03
# TotalSteps: 8.51e+04
# ValFuncLoss: 0.00327
# Variance: 0.591
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3055   0.1506   0.5836   0.5836   0.3055   0.1506
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0088   0.0035   0.0172   2.0347   0.7443   0.6515
# ***** Episode 744, Mean R = -87.9  Std R = 10.7  Min R = -115.1
# Beta: 0.0667
# ExplainedVarNew: 0.933
# ExplainedVarOld: 0.923
# KL: 0.00165
# PolicyEntropy: 2.58
# PolicyLoss: -0.00508
# Steps: 4.03e+03
# TotalSteps: 8.92e+04
# ValFuncLoss: 0.00332
# Variance: 0.593
# lr_multiplier: 1
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3043   0.1274   0.4770   0.5836   0.3055   0.1506
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0196   0.0104   0.0451   2.0347   0.7443   0.6515
# ***** Episode 775, Mean R = -86.2  Std R = 10.2  Min R = -115.9
# Beta: 0.0667
# ExplainedVarNew: 0.905
# ExplainedVarOld: 0.896
# KL: 0.00109
# PolicyEntropy: 2.57
# PolicyLoss: -0.00425
# Steps: 4.31e+03
# TotalSteps: 9.35e+04
# ValFuncLoss: 0.00289
# Variance: 0.594
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2977   0.1313   0.5081   0.5836   0.3055   0.1506
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0199   0.0109   0.0454   2.0347   0.7443   0.6515
# ***** Episode 806, Mean R = -83.2  Std R = 12.3  Min R = -125.8
# Beta: 0.0667
# ExplainedVarNew: 0.921
# ExplainedVarOld: 0.911
# KL: 0.00128
# PolicyEntropy: 2.56
# PolicyLoss: -0.00389
# Steps: 4.31e+03
# TotalSteps: 9.78e+04
# ValFuncLoss: 0.00233
# Variance: 0.59
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3180   0.1608   0.5741   0.5836   0.3180   0.1608
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0165   0.0077   0.0310   2.0347   0.7443   0.6515
# ***** Episode 837, Mean R = -84.2  Std R = 10.9  Min R = -105.8
# Beta: 0.0667
# ExplainedVarNew: 0.898
# ExplainedVarOld: 0.873
# KL: 0.00132
# PolicyEntropy: 2.54
# PolicyLoss: -0.00403
# Steps: 4.33e+03
# TotalSteps: 1.02e+05
# ValFuncLoss: 0.00248
# Variance: 0.585
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2838   0.1399   0.5224   0.5836   0.3180   0.1608
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0161   0.0086   0.0345   2.0347   0.7443   0.6515
# ***** Episode 868, Mean R = -82.1  Std R = 10.9  Min R = -105.6
# Beta: 0.0667
# ExplainedVarNew: 0.933
# ExplainedVarOld: 0.922
# KL: 0.00108
# PolicyEntropy: 2.52
# PolicyLoss: -0.00378
# Steps: 4.35e+03
# TotalSteps: 1.06e+05
# ValFuncLoss: 0.00194
# Variance: 0.586
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2356   0.1135   0.4287   0.5836   0.3180   0.1608
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0121   0.0067   0.0272   2.0347   0.7443   0.6515
# ***** Episode 899, Mean R = -81.2  Std R = 10.2  Min R = -102.4
# Beta: 0.0667
# ExplainedVarNew: 0.906
# ExplainedVarOld: 0.899
# KL: 0.00129
# PolicyEntropy: 2.52
# PolicyLoss: -0.00353
# Steps: 4.47e+03
# TotalSteps: 1.11e+05
# ValFuncLoss: 0.0021
# Variance: 0.587
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2547   0.0979   0.4056   0.5836   0.3180   0.1608
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0098   0.0050   0.0227   2.0347   0.7443   0.6515
# Update Cnt = 30    ET =    125.9   Stats:  Mean, Std, Min, Max
# r_f      |   312.6   -54.6    -2.5 |   582.1   503.2     1.6 |  -966.6 -1497.8    -6.4 |  1607.2  1468.2    -0.0
# v_f      |  -22.42   10.49 -102.47 |   10.21   20.33   14.08 |  -58.36  -45.78 -145.91 |    6.79   64.25  -50.31
# vr_f     |     4.4 |     4.8 |     1.3 |    55.2
# r_i      |  1023.6   -18.9  2349.3 |   581.9   574.5    27.6 |     1.1  -997.0  2300.3 |  1972.8   984.9  2399.8
# v_i      |  -40.15    1.00  -79.70 |   17.06   17.37    5.84 |  -69.90  -29.91  -89.94 |  -10.07   29.88  -70.05
# norm_rf  |   738.4 |   384.1 |    16.3 |  2127.7
# norm_vf  |  107.79 |   14.53 |   50.34 |  150.88
# thrust   |    1281     633    5488 |    6919    7255    6322 |  -15000  -14996  -14997 |   14998   15000   15000
# norm_thrust |   12735 |    3233 |    2000 |   15000
# fuel     |     170 |      20 |     128 |     253
# rewards  |  -85.81 |   11.88 | -130.19 |  -54.06
# fuel_rewards |   -5.85 |    0.68 |   -8.69 |   -4.42
# glideslope_rewards |    0.00 |    0.00 |    0.00 |    0.00
# glideslope_penalty |    0.00 |    0.00 |    0.00 |    0.00
# glideslope |    1.93 |    0.76 |    1.00 |    6.17
# sc_rewards |    0.00 |    0.00 |    0.00 |    0.00
# sc_penalty |    0.00 |    0.00 |    0.00 |    0.00
# sc_margin |  100.00 |    0.00 |  100.00 |  100.00
# range_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_margin |  733.84 |  383.30 |   69.83 | 2122.67
# tracking_rewards |  -79.96 |   12.00 | -124.56 |  -46.17
# steps    |     137 |      14 |     109 |     195
# ***** Episode 930, Mean R = -80.2  Std R = 9.7  Min R = -104.7
# Beta: 0.0667
# ExplainedVarNew: 0.892
# ExplainedVarOld: 0.881
# KL: 0.00101
# PolicyEntropy: 2.5
# PolicyLoss: -0.00416
# Steps: 4.52e+03
# TotalSteps: 1.15e+05
# ValFuncLoss: 0.00235
# Variance: 0.587
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3580   0.1530   0.6276   0.6276   0.3580   0.1608
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0158   0.0086   0.0382   2.0347   0.7443   0.6515
# ***** Episode 961, Mean R = -79.9  Std R = 12.7  Min R = -106.2
# Beta: 0.0667
# ExplainedVarNew: 0.914
# ExplainedVarOld: 0.891
# KL: 0.00176
# PolicyEntropy: 2.49
# PolicyLoss: -0.00441
# Steps: 4.75e+03
# TotalSteps: 1.2e+05
# ValFuncLoss: 0.00185
# Variance: 0.588
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3858   0.1844   0.6645   0.6645   0.3858   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0087   0.0048   0.0201   2.0347   0.7443   0.6515
# ***** Episode 992, Mean R = -80.3  Std R = 10.0  Min R = -106.7
# Beta: 0.0667
# ExplainedVarNew: 0.928
# ExplainedVarOld: 0.917
# KL: 0.00164
# PolicyEntropy: 2.47
# PolicyLoss: -0.00491
# Steps: 4.68e+03
# TotalSteps: 1.25e+05
# ValFuncLoss: 0.00112
# Variance: 0.584
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3741   0.1613   0.6491   0.6645   0.3858   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0100   0.0053   0.0247   2.0347   0.7443   0.6515
# ***** Episode 1023, Mean R = -78.5  Std R = 10.0  Min R = -101.4
# Beta: 0.0667
# ExplainedVarNew: 0.917
# ExplainedVarOld: 0.909
# KL: 0.00191
# PolicyEntropy: 2.44
# PolicyLoss: -0.00495
# Steps: 5.06e+03
# TotalSteps: 1.3e+05
# ValFuncLoss: 0.00118
# Variance: 0.58
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3481   0.1284   0.5391   0.6645   0.3858   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0088   0.0037   0.0179   2.0347   0.7443   0.6515
# ***** Episode 1054, Mean R = -78.5  Std R = 14.6  Min R = -120.2
# Beta: 0.0667
# ExplainedVarNew: 0.866
# ExplainedVarOld: 0.832
# KL: 0.00179
# PolicyEntropy: 2.42
# PolicyLoss: -0.00392
# Steps: 5.03e+03
# TotalSteps: 1.35e+05
# ValFuncLoss: 0.00218
# Variance: 0.578
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3916   0.1395   0.6435   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0210   0.0118   0.0512   2.0347   0.7443   0.6515
# ***** Episode 1085, Mean R = -72.6  Std R = 10.9  Min R = -92.6
# Beta: 0.0667
# ExplainedVarNew: 0.924
# ExplainedVarOld: 0.9
# KL: 0.00148
# PolicyEntropy: 2.4
# PolicyLoss: -0.00454
# Steps: 5.08e+03
# TotalSteps: 1.4e+05
# ValFuncLoss: 0.00124
# Variance: 0.572
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3304   0.1464   0.5615   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0106   0.0055   0.0240   2.0347   0.7443   0.6515
# ***** Episode 1116, Mean R = -72.7  Std R = 12.0  Min R = -103.0
# Beta: 0.0667
# ExplainedVarNew: 0.919
# ExplainedVarOld: 0.909
# KL: 0.00133
# PolicyEntropy: 2.38
# PolicyLoss: -0.00414
# Steps: 5.06e+03
# TotalSteps: 1.45e+05
# ValFuncLoss: 0.00117
# Variance: 0.57
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1436   0.0593   0.3161   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0608   0.0272   0.1262   2.0347   0.7443   0.6515
# ***** Episode 1147, Mean R = -84.1  Std R = 35.3  Min R = -213.2
# Beta: 0.0667
# ExplainedVarNew: 0.454
# ExplainedVarOld: -0.391
# KL: 0.000625
# PolicyEntropy: 2.38
# PolicyLoss: -0.00162
# Steps: 5.69e+03
# TotalSteps: 1.51e+05
# ValFuncLoss: 0.0126
# Variance: 0.57
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2122   0.0924   0.3773   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0277   0.0125   0.0540   2.0347   0.7443   0.6515
# ***** Episode 1178, Mean R = -72.5  Std R = 13.4  Min R = -98.9
# Beta: 0.0667
# ExplainedVarNew: 0.736
# ExplainedVarOld: 0.688
# KL: 0.000884
# PolicyEntropy: 2.36
# PolicyLoss: -0.00247
# Steps: 5.81e+03
# TotalSteps: 1.57e+05
# ValFuncLoss: 0.0036
# Variance: 0.569
# lr_multiplier: 1
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1721   0.0381   0.2269   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0199   0.0069   0.0386   2.0347   0.7443   0.6515
# ***** Episode 1209, Mean R = -83.4  Std R = 42.0  Min R = -253.6
# Beta: 0.0667
# ExplainedVarNew: 0.805
# ExplainedVarOld: 0.691
# KL: 0.000798
# PolicyEntropy: 2.36
# PolicyLoss: -0.00206
# Steps: 5.87e+03
# TotalSteps: 1.62e+05
# ValFuncLoss: 0.00427
# Variance: 0.568
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2201   0.0761   0.3493   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0308   0.0150   0.0715   2.0347   0.7443   0.6515
# Update Cnt = 40    ET =    152.3   Stats:  Mean, Std, Min, Max
# r_f      |   235.1   -74.8     9.8 |   411.0   299.4   101.5 |  -710.7  -875.6    -4.6 |  1221.2   816.4  1005.4
# v_f      |  -13.94    6.51  -67.91 |   10.42   16.40   23.34 |  -38.01  -31.22 -114.66 |   19.29   47.84   59.54
# vr_f     |     4.2 |     4.3 |     0.7 |    59.0
# r_i      |   960.9    30.2  2348.8 |   538.4   570.2    28.6 |     1.4  -995.5  2300.4 |  1998.3   998.4  2399.8
# v_i      |  -42.16   -0.86  -80.21 |   17.39   17.77    5.89 |  -69.75  -29.73  -89.74 |  -10.43   29.77  -70.11
# norm_rf  |   505.0 |   273.6 |    19.6 |  1469.0
# norm_vf  |   73.47 |   19.35 |   13.27 |  118.68
# thrust   |    1604     392    7616 |    6517    6954    5417 |  -14992  -14994  -14985 |   14996   14999   14999
# norm_thrust |   13111 |    3001 |    2000 |   15000
# fuel     |     217 |      56 |     146 |     614
# rewards  |  -77.42 |   21.16 | -253.60 |  -46.58
# fuel_rewards |   -7.47 |    1.91 |  -21.08 |   -5.02
# glideslope_rewards |    0.00 |    0.00 |    0.00 |    0.00
# glideslope_penalty |    0.00 |    0.00 |    0.00 |    0.00
# glideslope |    1.68 |    0.62 |    0.05 |    5.51
# sc_rewards |    0.00 |    0.00 |    0.00 |    0.00
# sc_penalty |    0.00 |    0.00 |    0.00 |    0.00
# sc_margin |  100.00 |    0.00 |  100.00 |  100.00
# range_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_margin |  500.50 |  272.71 |   44.43 | 1464.00
# tracking_rewards |  -69.95 |   20.26 | -232.53 |  -38.37
# steps    |     170 |      42 |     118 |     477
# ***** Episode 1240, Mean R = -71.7  Std R = 15.9  Min R = -109.5
# Beta: 0.0667
# ExplainedVarNew: 0.872
# ExplainedVarOld: 0.842
# KL: 0.000814
# PolicyEntropy: 2.34
# PolicyLoss: -0.00278
# Steps: 5.73e+03
# TotalSteps: 1.68e+05
# ValFuncLoss: 0.00285
# Variance: 0.565
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1070   0.0346   0.1869   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0499   0.0205   0.0952   2.0347   0.7443   0.6515
# ***** Episode 1271, Mean R = -89.2  Std R = 46.2  Min R = -217.3
# Beta: 0.0667
# ExplainedVarNew: 0.742
# ExplainedVarOld: 0.598
# KL: 0.000616
# PolicyEntropy: 2.34
# PolicyLoss: -0.00133
# Steps: 6.47e+03
# TotalSteps: 1.75e+05
# ValFuncLoss: 0.00861
# Variance: 0.568
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1836   0.0706   0.3663   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0191   0.0088   0.0374   2.0347   0.7443   0.6515
# ***** Episode 1302, Mean R = -92.2  Std R = 50.5  Min R = -219.9
# Beta: 0.0667
# ExplainedVarNew: 0.831
# ExplainedVarOld: 0.806
# KL: 0.00113
# PolicyEntropy: 2.34
# PolicyLoss: -0.00243
# Steps: 6.82e+03
# TotalSteps: 1.81e+05
# ValFuncLoss: 0.00609
# Variance: 0.57
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2267   0.0672   0.3803   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0110   0.0057   0.0252   2.0347   0.7443   0.6515
# ***** Episode 1333, Mean R = -68.9  Std R = 22.8  Min R = -184.3
# Beta: 0.0667
# ExplainedVarNew: 0.885
# ExplainedVarOld: 0.867
# KL: 0.000842
# PolicyEntropy: 2.33
# PolicyLoss: -0.00293
# Steps: 6.07e+03
# TotalSteps: 1.88e+05
# ValFuncLoss: 0.00259
# Variance: 0.568
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2374   0.0839   0.4890   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0111   0.0065   0.0285   2.0347   0.7443   0.6515
# ***** Episode 1364, Mean R = -97.6  Std R = 58.8  Min R = -223.1
# Beta: 0.0667
# ExplainedVarNew: 0.882
# ExplainedVarOld: 0.861
# KL: 0.000784
# PolicyEntropy: 2.32
# PolicyLoss: -0.0026
# Steps: 7.53e+03
# TotalSteps: 1.95e+05
# ValFuncLoss: 0.00577
# Variance: 0.57
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1796   0.0633   0.3051   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0258   0.0115   0.0455   2.0347   0.7443   0.6515
# ***** Episode 1395, Mean R = -113.0  Std R = 68.7  Min R = -244.0
# Beta: 0.0667
# ExplainedVarNew: 0.881
# ExplainedVarOld: 0.865
# KL: 0.000765
# PolicyEntropy: 2.32
# PolicyLoss: -0.0017
# Steps: 8.2e+03
# TotalSteps: 2.03e+05
# ValFuncLoss: 0.00647
# Variance: 0.567
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1396   0.0431   0.2595   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0130   0.0057   0.0258   2.0347   0.7443   0.6515
# ***** Episode 1426, Mean R = -104.1  Std R = 67.1  Min R = -229.3
# Beta: 0.0667
# ExplainedVarNew: 0.871
# ExplainedVarOld: 0.867
# KL: 0.0009
# PolicyEntropy: 2.31
# PolicyLoss: -0.00194
# Steps: 7.96e+03
# TotalSteps: 2.11e+05
# ValFuncLoss: 0.00747
# Variance: 0.567
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2785   0.1157   0.6084   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0099   0.0038   0.0194   2.0347   0.7443   0.6515
# ***** Episode 1457, Mean R = -103.6  Std R = 66.8  Min R = -234.8
# Beta: 0.0667
# ExplainedVarNew: 0.86
# ExplainedVarOld: 0.853
# KL: 0.00104
# PolicyEntropy: 2.32
# PolicyLoss: -0.00207
# Steps: 8.54e+03
# TotalSteps: 2.2e+05
# ValFuncLoss: 0.00874
# Variance: 0.57
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2568   0.0977   0.5204   0.6645   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0138   0.0070   0.0332   2.0347   0.7443   0.6515
# ***** Episode 1488, Mean R = -89.3  Std R = 51.6  Min R = -210.0
# Beta: 0.0667
# ExplainedVarNew: 0.891
# ExplainedVarOld: 0.866
# KL: 0.000798
# PolicyEntropy: 2.32
# PolicyLoss: -0.00264
# Steps: 7.34e+03
# TotalSteps: 2.27e+05
# ValFuncLoss: 0.00518
# Variance: 0.57
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3801   0.1460   0.7024   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0180   0.0088   0.0383   2.0347   0.7443   0.6515
# ***** Episode 1519, Mean R = -101.6  Std R = 69.8  Min R = -259.5
# Beta: 0.0667
# ExplainedVarNew: 0.923
# ExplainedVarOld: 0.918
# KL: 0.000938
# PolicyEntropy: 2.31
# PolicyLoss: -0.00264
# Steps: 8.14e+03
# TotalSteps: 2.35e+05
# ValFuncLoss: 0.00504
# Variance: 0.568
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2248   0.0885   0.4175   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0104   0.0038   0.0195   2.0347   0.7443   0.6515
# Update Cnt = 50    ET =    211.0   Stats:  Mean, Std, Min, Max
# r_f      |   201.6   -36.7   199.8 |   267.8   153.1   408.8 |  -673.5  -613.3    -3.8 |  1093.4   441.2  1531.0
# v_f      |   -8.38    4.16  -27.95 |   13.61   13.21   41.47 |  -40.40  -32.80  -91.28 |   18.40   40.63   57.30
# vr_f     |     4.2 |     7.6 |     0.5 |    96.8
# r_i      |   994.0    43.3  2351.1 |   564.7   549.5    30.0 |     0.5  -988.6  2300.1 |  1997.9   983.1  2399.8
# v_i      |  -39.79   -2.29  -79.80 |   17.87   16.82    5.75 |  -69.92  -29.89  -89.96 |  -10.32   29.70  -70.00
# norm_rf  |   464.9 |   357.8 |     4.4 |  1592.5
# norm_vf  |   51.94 |   15.83 |    6.33 |   96.69
# thrust   |    1242     265    8577 |    6280    6770    4961 |  -14992  -15000  -14854 |   15000   14999   15000
# norm_thrust |   13300 |    2856 |    2000 |   15000
# fuel     |     310 |     120 |     169 |     644
# rewards  |  -94.57 |   58.40 | -259.46 |  -34.64
# fuel_rewards |  -10.64 |    4.12 |  -22.12 |   -5.82
# glideslope_rewards |    0.00 |    0.00 |    0.00 |    0.00
# glideslope_penalty |    0.00 |    0.00 |    0.00 |    0.00
# glideslope |    1.19 |    0.72 |    0.02 |    4.35
# sc_rewards |    0.00 |    0.00 |    0.00 |    0.00
# sc_penalty |    0.00 |    0.00 |    0.00 |    0.00
# sc_margin |  100.00 |    0.00 |  100.00 |  100.00
# range_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_margin |  460.32 |  357.33 |   37.65 | 1587.53
# tracking_rewards |  -83.93 |   54.88 | -239.57 |  -25.26
# steps    |     239 |      93 |     132 |     500
# ***** Episode 1550, Mean R = -86.3  Std R = 53.4  Min R = -238.8
# Beta: 0.0667
# ExplainedVarNew: 0.934
# ExplainedVarOld: 0.928
# KL: 0.00093
# PolicyEntropy: 2.3
# PolicyLoss: -0.00243
# Steps: 7.13e+03
# TotalSteps: 2.42e+05
# ValFuncLoss: 0.00396
# Variance: 0.57
# lr_multiplier: 1
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2477   0.1154   0.5095   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0189   0.0088   0.0370   2.0347   0.7443   0.6515
# ***** Episode 1581, Mean R = -94.9  Std R = 57.6  Min R = -231.0
# Beta: 0.0667
# ExplainedVarNew: 0.854
# ExplainedVarOld: 0.827
# KL: 0.000705
# PolicyEntropy: 2.3
# PolicyLoss: -0.002
# Steps: 7.69e+03
# TotalSteps: 2.5e+05
# ValFuncLoss: 0.0072
# Variance: 0.572
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3383   0.1586   0.6893   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0154   0.0083   0.0405   2.0347   0.7443   0.6515
# ***** Episode 1612, Mean R = -80.8  Std R = 59.9  Min R = -224.7
# Beta: 0.0667
# ExplainedVarNew: 0.894
# ExplainedVarOld: 0.886
# KL: 0.000806
# PolicyEntropy: 2.3
# PolicyLoss: -0.00303
# Steps: 7.71e+03
# TotalSteps: 2.58e+05
# ValFuncLoss: 0.005
# Variance: 0.57
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3149   0.1275   0.5987   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0212   0.0090   0.0415   2.0347   0.7443   0.6515
# ***** Episode 1643, Mean R = -97.3  Std R = 76.1  Min R = -265.5
# Beta: 0.0667
# ExplainedVarNew: 0.921
# ExplainedVarOld: 0.898
# KL: 0.000647
# PolicyEntropy: 2.3
# PolicyLoss: -0.00225
# Steps: 8.39e+03
# TotalSteps: 2.66e+05
# ValFuncLoss: 0.00553
# Variance: 0.57
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2523   0.1106   0.4916   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0076   0.0036   0.0152   2.0347   0.7443   0.6515
# ***** Episode 1674, Mean R = -84.3  Std R = 60.6  Min R = -240.7
# Beta: 0.1
# ExplainedVarNew: 0.926
# ExplainedVarOld: 0.915
# KL: 0.000471
# PolicyEntropy: 2.31
# PolicyLoss: -0.00208
# Steps: 7.84e+03
# TotalSteps: 2.74e+05
# ValFuncLoss: 0.00442
# Variance: 0.574
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2549   0.0978   0.4987   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0075   0.0044   0.0173   2.0347   0.7443   0.6515
# ***** Episode 1705, Mean R = -85.2  Std R = 59.5  Min R = -244.6
# Beta: 0.1
# ExplainedVarNew: 0.888
# ExplainedVarOld: 0.877
# KL: 0.00188
# PolicyEntropy: 2.3
# PolicyLoss: -0.00305
# Steps: 7.76e+03
# TotalSteps: 2.82e+05
# ValFuncLoss: 0.00631
# Variance: 0.573
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2940   0.1166   0.5207   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0084   0.0035   0.0183   2.0347   0.7443   0.6515
# ***** Episode 1736, Mean R = -106.6  Std R = 85.1  Min R = -295.4
# Beta: 0.1
# ExplainedVarNew: 0.939
# ExplainedVarOld: 0.934
# KL: 0.00167
# PolicyEntropy: 2.3
# PolicyLoss: -0.00263
# Steps: 8.4e+03
# TotalSteps: 2.9e+05
# ValFuncLoss: 0.00516
# Variance: 0.572
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2366   0.0781   0.4002   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0109   0.0059   0.0243   2.0347   0.7443   0.6515
# ***** Episode 1767, Mean R = -92.5  Std R = 81.8  Min R = -276.0
# Beta: 0.1
# ExplainedVarNew: 0.93
# ExplainedVarOld: 0.924
# KL: 0.00188
# PolicyEntropy: 2.29
# PolicyLoss: -0.00226
# Steps: 8.67e+03
# TotalSteps: 2.99e+05
# ValFuncLoss: 0.00434
# Variance: 0.57
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1919   0.0506   0.2943   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0079   0.0033   0.0172   2.0347   0.7443   0.6515
# ***** Episode 1798, Mean R = -71.5  Std R = 53.2  Min R = -264.0
# Beta: 0.1
# ExplainedVarNew: 0.913
# ExplainedVarOld: 0.889
# KL: 0.00138
# PolicyEntropy: 2.28
# PolicyLoss: -0.00339
# Steps: 7.31e+03
# TotalSteps: 3.06e+05
# ValFuncLoss: 0.00271
# Variance: 0.566
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.1421   0.0392   0.2452   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0301   0.0102   0.0521   2.0347   0.7443   0.6515
# ***** Episode 1829, Mean R = -84.2  Std R = 76.1  Min R = -305.0
# Beta: 0.1
# ExplainedVarNew: 0.94
# ExplainedVarOld: 0.896
# KL: 0.00159
# PolicyEntropy: 2.27
# PolicyLoss: -0.00247
# Steps: 8.07e+03
# TotalSteps: 3.14e+05
# ValFuncLoss: 0.00408
# Variance: 0.565
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3414   0.1381   0.6115   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0122   0.0052   0.0248   2.0347   0.7443   0.6515
# Update Cnt = 60    ET =    222.9   Stats:  Mean, Std, Min, Max
# r_f      |    74.6    10.2   151.5 |   170.8   107.4   370.0 |  -495.1  -392.8    -3.4 |   892.4   427.3  1804.6
# v_f      |  -12.25    2.63  -28.63 |   13.23    8.65   32.24 |  -47.24  -21.46  -77.86 |   22.46   30.08   52.90
# vr_f     |     3.0 |     2.2 |     0.4 |    15.2
# r_i      |  1019.7    39.3  2352.2 |   570.5   588.2    29.3 |    11.7  -988.3  2300.5 |  1995.7   986.2  2399.6
# v_i      |  -39.81    0.32  -79.74 |   16.97   16.22    5.88 |  -69.95  -29.94  -89.95 |  -10.08   29.86  -70.03
# norm_rf  |   297.3 |   343.3 |     4.7 |  1887.1
# norm_vf  |   44.80 |   16.11 |    4.70 |   89.21
# thrust   |     996      75    8441 |    6286    6821    5023 |  -14993  -14998  -14964 |   14999   14999   15000
# norm_thrust |   13230 |    2915 |    2000 |   15000
# fuel     |     333 |     122 |     182 |     642
# rewards  |  -89.15 |   70.29 | -317.93 |  -35.30
# fuel_rewards |  -11.45 |    4.19 |  -22.04 |   -6.29
# glideslope_rewards |    0.00 |    0.00 |    0.00 |    0.00
# glideslope_penalty |    0.00 |    0.00 |    0.00 |    0.00
# glideslope |    1.13 |    0.62 |    0.03 |    3.13
# sc_rewards |    0.00 |    0.00 |    0.00 |    0.00
# sc_penalty |    0.00 |    0.00 |    0.00 |    0.00
# sc_margin |  100.00 |    0.00 |  100.00 |  100.00
# range_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_margin |  293.89 |  342.07 |   18.64 | 1882.09
# tracking_rewards |  -77.70 |   66.69 | -296.19 |  -24.45
# steps    |     259 |      99 |     145 |     500
# ***** Episode 1860, Mean R = -94.2  Std R = 77.9  Min R = -317.9
# Beta: 0.1
# ExplainedVarNew: 0.916
# ExplainedVarOld: 0.901
# KL: 0.00161
# PolicyEntropy: 2.25
# PolicyLoss: -0.00331
# Steps: 8.44e+03
# TotalSteps: 3.23e+05
# ValFuncLoss: 0.00453
# Variance: 0.56
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2824   0.1167   0.5034   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0085   0.0033   0.0161   2.0347   0.7443   0.6515
# ***** Episode 1891, Mean R = -95.4  Std R = 83.3  Min R = -301.6
# Beta: 0.1
# ExplainedVarNew: 0.951
# ExplainedVarOld: 0.945
# KL: 0.00186
# PolicyEntropy: 2.24
# PolicyLoss: -0.00307
# Steps: 8.38e+03
# TotalSteps: 3.31e+05
# ValFuncLoss: 0.00362
# Variance: 0.557
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.3256   0.1511   0.6175   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0111   0.0049   0.0222   2.0347   0.7443   0.6515
# ***** Episode 1922, Mean R = -100.9  Std R = 95.1  Min R = -362.3
# Beta: 0.1
# ExplainedVarNew: 0.935
# ExplainedVarOld: 0.93
# KL: 0.002
# PolicyEntropy: 2.23
# PolicyLoss: -0.00296
# Steps: 8.65e+03
# TotalSteps: 3.4e+05
# ValFuncLoss: 0.00497
# Variance: 0.556
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2595   0.0936   0.3996   0.7024   0.3916   0.1844
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0047   0.0017   0.0089   2.0347   0.7443   0.6515
# ***** Episode 1953, Mean R = -62.1  Std R = 38.7  Min R = -267.3
# Beta: 0.1
# ExplainedVarNew: 0.889
# ExplainedVarOld: 0.876
# KL: 0.00178
# PolicyEntropy: 2.22
# PolicyLoss: -0.00641
# Steps: 7.17e+03
# TotalSteps: 3.47e+05
# ValFuncLoss: 0.00317
# Variance: 0.553
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.4795   0.1989   0.8313   0.8313   0.4795   0.1989
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0087   0.0031   0.0172   2.0347   0.7443   0.6515
# ***** Episode 1984, Mean R = -72.9  Std R = 51.6  Min R = -263.6
# Beta: 0.1
# ExplainedVarNew: 0.924
# ExplainedVarOld: 0.906
# KL: 0.00174
# PolicyEntropy: 2.21
# PolicyLoss: -0.00548
# Steps: 8.19e+03
# TotalSteps: 3.55e+05
# ValFuncLoss: 0.0032
# Variance: 0.55
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2333   0.0460   0.3278   0.8313   0.4795   0.1989
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0078   0.0043   0.0191   2.0347   0.7443   0.6515
# ***** Episode 2015, Mean R = -52.7  Std R = 13.6  Min R = -91.0
# Beta: 0.1
# ExplainedVarNew: 0.875
# ExplainedVarOld: 0.866
# KL: 0.00185
# PolicyEntropy: 2.21
# PolicyLoss: -0.0059
# Steps: 7.26e+03
# TotalSteps: 3.62e+05
# ValFuncLoss: 0.00249
# Variance: 0.548
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2219   0.0613   0.3659   0.8313   0.4795   0.1989
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0057   0.0026   0.0105   2.0347   0.7443   0.6515
# ***** Episode 2046, Mean R = -58.2  Std R = 25.0  Min R = -181.2
# Beta: 0.0667
# ExplainedVarNew: 0.908
# ExplainedVarOld: 0.887
# KL: 0.00222
# PolicyEntropy: 2.19
# PolicyLoss: -0.00407
# Steps: 7.35e+03
# TotalSteps: 3.7e+05
# ValFuncLoss: 0.00242
# Variance: 0.544
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2687   0.0835   0.4610   0.8313   0.4795   0.1989
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0064   0.0036   0.0154   2.0347   0.7443   0.6515
# ***** Episode 2077, Mean R = -47.7  Std R = 8.9  Min R = -72.2
# Beta: 0.0667
# ExplainedVarNew: 0.872
# ExplainedVarOld: 0.863
# KL: 0.00121
# PolicyEntropy: 2.18
# PolicyLoss: -0.00402
# Steps: 7.09e+03
# TotalSteps: 3.77e+05
# ValFuncLoss: 0.00179
# Variance: 0.539
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2123   0.0595   0.3594   0.8313   0.4795   0.1989
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0028   0.0013   0.0055   2.0347   0.7443   0.6515
# ***** Episode 2108, Mean R = -49.8  Std R = 9.6  Min R = -77.4
# Beta: 0.0667
# ExplainedVarNew: 0.876
# ExplainedVarOld: 0.866
# KL: 0.00115
# PolicyEntropy: 2.17
# PolicyLoss: -0.00435
# Steps: 7.28e+03
# TotalSteps: 3.84e+05
# ValFuncLoss: 0.00178
# Variance: 0.539
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2354   0.0515   0.3267   0.8313   0.4795   0.1989
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0058   0.0031   0.0131   2.0347   0.7443   0.6515
# ***** Episode 2139, Mean R = -49.0  Std R = 10.0  Min R = -73.8
# Beta: 0.0667
# ExplainedVarNew: 0.911
# ExplainedVarOld: 0.906
# KL: 0.00109
# PolicyEntropy: 2.14
# PolicyLoss: -0.00433
# Steps: 7.06e+03
# TotalSteps: 3.91e+05
# ValFuncLoss: 0.002
# Variance: 0.536
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2936   0.1209   0.5823   0.8313   0.4795   0.1989
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0025   0.0011   0.0049   2.0347   0.7443   0.6515
# Update Cnt = 70    ET =    218.0   Stats:  Mean, Std, Min, Max
# r_f      |    27.4    -3.7    34.4 |   116.3    98.3   197.9 |  -235.2  -297.5    -3.0 |   502.0   266.0  1484.1
# v_f      |  -12.42    2.88  -37.62 |    8.29    6.96   15.77 |  -48.51  -14.70  -67.73 |   13.94   25.21   41.63
# vr_f     |     3.3 |     2.8 |     0.3 |    38.1
# r_i      |  1025.4   -55.9  2348.9 |   578.5   563.8    30.0 |    13.2  -992.4  2300.3 |  1996.7   990.3  2399.9
# v_i      |  -39.38    0.23  -80.00 |   17.34   17.45    5.96 |  -69.95  -29.83  -89.84 |  -10.65   29.87  -70.16
# norm_rf  |   159.4 |   197.2 |    10.3 |  1524.0
# norm_vf  |   42.72 |   10.91 |    2.26 |   81.75
# thrust   |    1064     111    8339 |    6233    6707    5144 |  -14999  -14997  -14791 |   15000   14999   15000
# norm_thrust |   13114 |    3002 |    2000 |   15000
# fuel     |     312 |      83 |     204 |     627
# rewards  |  -63.60 |   49.86 | -362.30 |  -33.68
# fuel_rewards |  -10.72 |    2.83 |  -21.52 |   -7.02
# glideslope_rewards |    0.00 |    0.00 |    0.00 |    0.00
# glideslope_penalty |    0.00 |    0.00 |    0.00 |    0.00
# glideslope |    1.35 |    0.51 |    0.02 |    3.13
# sc_rewards |    0.00 |    0.00 |    0.00 |    0.00
# sc_penalty |    0.00 |    0.00 |    0.00 |    0.00
# sc_margin |  100.00 |    0.00 |  100.00 |  100.00
# range_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_margin |  155.88 |  196.29 |   28.97 | 1519.02
# tracking_rewards |  -52.88 |   47.62 | -341.14 |  -23.62
# steps    |     244 |      69 |     151 |     500
# ***** Episode 2170, Mean R = -47.4  Std R = 8.6  Min R = -71.2
# Beta: 0.0667
# ExplainedVarNew: 0.882
# ExplainedVarOld: 0.878
# KL: 0.00123
# PolicyEntropy: 2.13
# PolicyLoss: -0.00379
# Steps: 7.35e+03
# TotalSteps: 3.98e+05
# ValFuncLoss: 0.00181
# Variance: 0.532
# lr_multiplier: 1
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.2554   0.1100   0.5164   0.8313   0.4795   0.1989
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0067   0.0037   0.0162   2.0347   0.7443   0.6515
# ...
# v_f      |   -1.38   -0.14   -3.91 |    1.21    1.25    0.61 |   -3.90   -3.01   -6.49 |    1.99    3.98   -2.56
# vr_f     |     2.8 |     3.8 |     0.8 |    55.5
# r_i      |   994.3    31.9  2348.3 |   592.3   571.3    29.0 |     0.7  -988.2  2300.5 |  1992.4   979.6  2399.9
# v_i      |  -39.38   -0.31  -80.07 |   17.15   17.26    5.58 |  -69.83  -29.95  -89.90 |  -10.12   29.94  -70.02
# norm_rf  |     1.5 |     0.9 |     0.2 |     6.9
# norm_vf  |    4.50 |    0.58 |    3.04 |    7.71
# thrust   |    1303      12    9438 |    2435    2476    1866 |   -9263  -14249    1955 |   14469   13227   14997
# norm_thrust |   10028 |    2402 |    2784 |   15000
# fuel     |     270 |      13 |     237 |     305
# rewards  |  -23.20 |    7.41 |  -51.16 |  -10.96
# fuel_rewards |   -9.29 |    0.44 |  -10.50 |   -8.14
# glideslope_rewards |    0.00 |    0.00 |    0.00 |    0.00
# glideslope_penalty |    0.00 |    0.00 |    0.00 |    0.00
# glideslope |    1.60 |    0.68 |    0.77 |    7.28
# sc_rewards |    0.00 |    0.00 |    0.00 |    0.00
# sc_penalty |    0.00 |    0.00 |    0.00 |    0.00
# sc_margin |  100.00 |    0.00 |  100.00 |  100.00
# range_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_margin |    2.50 |    0.58 |    1.04 |    5.71
# tracking_rewards |  -13.91 |    7.24 |  -41.57 |   -2.23
# steps    |     277 |      17 |     231 |     312
# ***** Episode 89280, Mean R = -26.1  Std R = 7.1  Min R = -41.8
# Beta: 0.0759
# ExplainedVarNew: 0.996
# ExplainedVarOld: 0.995
# KL: 0.000559
# PolicyEntropy: -4.94
# PolicyLoss: -0.00274
# Steps: 8.51e+03
# TotalSteps: 2.44e+07
# ValFuncLoss: 0.000949
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   8.9313   1.7249  13.1345  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0011   0.0007   0.0026   2.0347   0.7443   0.6515
# ***** Episode 89311, Mean R = -24.6  Std R = 6.7  Min R = -40.0
# Beta: 0.0759
# ExplainedVarNew: 0.994
# ExplainedVarOld: 0.993
# KL: 0.000928
# PolicyEntropy: -4.94
# PolicyLoss: -0.0026
# Steps: 8.65e+03
# TotalSteps: 2.44e+07
# ValFuncLoss: 0.000656
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   6.2298   1.8911   9.8186  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0007   0.0004   0.0015   2.0347   0.7443   0.6515
# ***** Episode 89342, Mean R = -22.4  Std R = 6.5  Min R = -42.0
# Beta: 0.0759
# ExplainedVarNew: 0.991
# ExplainedVarOld: 0.992
# KL: 0.000707
# PolicyEntropy: -4.94
# PolicyLoss: -0.00211
# Steps: 8.71e+03
# TotalSteps: 2.44e+07
# ValFuncLoss: 0.000818
# Variance: 0.0581
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   7.5373   1.5809  10.3256  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0016   0.0009   0.0038   2.0347   0.7443   0.6515
# ***** Episode 89373, Mean R = -22.8  Std R = 7.9  Min R = -46.9
# Beta: 0.0759
# ExplainedVarNew: 0.995
# ExplainedVarOld: 0.994
# KL: 0.00079
# PolicyEntropy: -4.94
# PolicyLoss: -0.00223
# Steps: 8.44e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.000883
# Variance: 0.0581
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   7.7548   2.1171  12.7932  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0012   0.0008   0.0028   2.0347   0.7443   0.6515
# ***** Episode 89404, Mean R = -24.3  Std R = 8.6  Min R = -41.2
# Beta: 0.0759
# ExplainedVarNew: 0.994
# ExplainedVarOld: 0.994
# KL: 0.000792
# PolicyEntropy: -4.94
# PolicyLoss: -0.00285
# Steps: 8.65e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.000658
# Variance: 0.0581
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   7.7545   2.7548  13.6991  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0007   0.0004   0.0015   2.0347   0.7443   0.6515
# ***** Episode 89435, Mean R = -23.7  Std R = 7.5  Min R = -40.3
# Beta: 0.0759
# ExplainedVarNew: 0.996
# ExplainedVarOld: 0.995
# KL: 0.00089
# PolicyEntropy: -4.94
# PolicyLoss: -0.00309
# Steps: 8.58e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.000711
# Variance: 0.0581
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   7.5602   1.9441  11.9657  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0002   0.0001   0.0004   2.0347   0.7443   0.6515
# ***** Episode 89466, Mean R = -23.6  Std R = 8.0  Min R = -50.9
# Beta: 0.0759
# ExplainedVarNew: 0.995
# ExplainedVarOld: 0.995
# KL: 0.000735
# PolicyEntropy: -4.94
# PolicyLoss: -0.00206
# Steps: 8.85e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.000497
# Variance: 0.0581
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :  14.4231   6.1752  24.0740  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0004   0.0002   0.0009   2.0347   0.7443   0.6515
# ***** Episode 89497, Mean R = -22.8  Std R = 7.4  Min R = -40.1
# Beta: 0.0759
# ExplainedVarNew: 0.993
# ExplainedVarOld: 0.995
# KL: 0.000868
# PolicyEntropy: -4.94
# PolicyLoss: -0.00251
# Steps: 8.55e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.000707
# Variance: 0.0581
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   7.8427   2.9650  13.7958  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0006   0.0004   0.0014   2.0347   0.7443   0.6515
# ***** Episode 89528, Mean R = -23.2  Std R = 5.9  Min R = -39.6
# Beta: 0.0759
# ExplainedVarNew: 0.995
# ExplainedVarOld: 0.994
# KL: 0.000732
# PolicyEntropy: -4.94
# PolicyLoss: -0.00231
# Steps: 8.67e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.000655
# Variance: 0.0581
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :  14.0139   4.8774  23.8790  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0005   0.0002   0.0010   2.0347   0.7443   0.6515
# ***** Episode 89559, Mean R = -25.0  Std R = 6.1  Min R = -41.6
# Beta: 0.0759
# ExplainedVarNew: 0.995
# ExplainedVarOld: 0.996
# KL: 0.00102
# PolicyEntropy: -4.94
# PolicyLoss: -0.00282
# Steps: 8.52e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.000974
# Variance: 0.0581
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :  16.3357   5.5985  25.7008  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0013   0.0007   0.0029   2.0347   0.7443   0.6515
# Update Cnt = 2890    ET =    290.2   Stats:  Mean, Std, Min, Max
# r_f      |     0.9     0.0    -0.1 |     1.1     0.9     0.1 |    -2.5    -3.8    -0.2 |     5.2     5.6    -0.0
# v_f      |   -1.45   -0.04   -3.90 |    1.13    1.24    0.58 |   -4.42   -3.60   -5.89 |    1.40    3.52   -2.36
# vr_f     |     2.9 |     3.4 |     0.7 |    39.3
# r_i      |  1019.6   -10.0  2350.7 |   568.1   560.7    28.8 |     4.8  -993.4  2300.0 |  1993.5   997.0  2399.6
# v_i      |  -40.31   -2.01  -79.75 |   17.21   17.80    5.83 |  -69.67  -29.88  -89.83 |  -10.68   29.92  -70.03
# norm_rf  |     1.4 |     0.9 |     0.1 |     7.7
# norm_vf  |    4.48 |    0.58 |    3.01 |    7.01
# thrust   |    1316      84    9390 |    2494    2529    1856 |   -8890  -13410     774 |   14854   13806   14999
# norm_thrust |   10006 |    2418 |    2582 |   15000
# fuel     |     270 |      13 |     236 |     318
# rewards  |  -23.85 |    7.35 |  -50.88 |  -11.19
# fuel_rewards |   -9.29 |    0.46 |  -10.91 |   -8.11
# glideslope_rewards |    0.00 |    0.00 |    0.00 |    0.00
# glideslope_penalty |    0.00 |    0.00 |    0.00 |    0.00
# glideslope |    1.52 |    0.54 |    0.72 |    4.27
# sc_rewards |    0.00 |    0.00 |    0.00 |    0.00
# sc_penalty |    0.00 |    0.00 |    0.00 |    0.00
# sc_margin |  100.00 |    0.00 |  100.00 |  100.00
# range_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_margin |    2.48 |    0.58 |    1.01 |    5.01
# tracking_rewards |  -14.56 |    7.16 |  -40.30 |   -2.41
# steps    |     278 |      17 |     238 |     318
# ***** Episode 89590, Mean R = -26.1  Std R = 7.7  Min R = -38.7
# Beta: 0.0759
# ExplainedVarNew: 0.996
# ExplainedVarOld: 0.996
# KL: 0.000906
# PolicyEntropy: -4.94
# PolicyLoss: -0.00191
# Steps: 8.53e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.000773
# Variance: 0.0581
# lr_multiplier: 0.0878
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   9.1293   3.4891  17.4819  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0003   0.0001   0.0006   2.0347   0.7443   0.6515
# ***** Episode 89621, Mean R = -23.6  Std R = 6.4  Min R = -38.7
# Beta: 0.0759
# ExplainedVarNew: 0.994
# ExplainedVarOld: 0.993
# KL: 0.000732
# PolicyEntropy: -4.94
# PolicyLoss: -0.0021
# Steps: 8.64e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.000774
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :  11.0025   3.6256  18.5947  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0007   0.0004   0.0015   2.0347   0.7443   0.6515
# ***** Episode 89652, Mean R = -24.9  Std R = 5.9  Min R = -36.7
# Beta: 0.0759
# ExplainedVarNew: 0.992
# ExplainedVarOld: 0.993
# KL: 0.00117
# PolicyEntropy: -4.94
# PolicyLoss: -0.00222
# Steps: 8.57e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.00101
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   7.1359   1.7099  11.5766  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0006   0.0003   0.0012   2.0347   0.7443   0.6515
# ***** Episode 89683, Mean R = -22.4  Std R = 5.9  Min R = -32.8
# Beta: 0.0759
# ExplainedVarNew: 0.99
# ExplainedVarOld: 0.988
# KL: 0.000781
# PolicyEntropy: -4.94
# PolicyLoss: -0.0028
# Steps: 8.68e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.00085
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :  12.0707   5.1371  20.4717  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0003   0.0001   0.0006   2.0347   0.7443   0.6515
# ***** Episode 89714, Mean R = -22.7  Std R = 7.4  Min R = -39.8
# Beta: 0.0759
# ExplainedVarNew: 0.992
# ExplainedVarOld: 0.991
# KL: 0.000587
# PolicyEntropy: -4.94
# PolicyLoss: -0.00255
# Steps: 8.64e+03
# TotalSteps: 2.45e+07
# ValFuncLoss: 0.000772
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   7.1031   2.6800  13.1674  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0005   0.0003   0.0012   2.0347   0.7443   0.6515
# ***** Episode 89745, Mean R = -23.5  Std R = 6.9  Min R = -36.9
# Beta: 0.0759
# ExplainedVarNew: 0.991
# ExplainedVarOld: 0.991
# KL: 0.000693
# PolicyEntropy: -4.94
# PolicyLoss: -0.00279
# Steps: 8.42e+03
# TotalSteps: 2.46e+07
# ValFuncLoss: 0.000829
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   9.1967   3.7105  17.6199  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0014   0.0008   0.0032   2.0347   0.7443   0.6515
# ***** Episode 89776, Mean R = -23.8  Std R = 5.9  Min R = -38.6
# Beta: 0.0759
# ExplainedVarNew: 0.995
# ExplainedVarOld: 0.993
# KL: 0.000735
# PolicyEntropy: -4.94
# PolicyLoss: -0.00236
# Steps: 8.61e+03
# TotalSteps: 2.46e+07
# ValFuncLoss: 0.000751
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   9.0871   3.3030  16.7558  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0010   0.0005   0.0020   2.0347   0.7443   0.6515
# ***** Episode 89807, Mean R = -23.5  Std R = 7.3  Min R = -47.3
# Beta: 0.0759
# ExplainedVarNew: 0.994
# ExplainedVarOld: 0.993
# KL: 0.000862
# PolicyEntropy: -4.94
# PolicyLoss: -0.00228
# Steps: 8.64e+03
# TotalSteps: 2.46e+07
# ValFuncLoss: 0.000799
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :  20.0377   8.6980  35.6367  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0006   0.0003   0.0014   2.0347   0.7443   0.6515
# ***** Episode 89838, Mean R = -25.9  Std R = 8.5  Min R = -47.4
# Beta: 0.0759
# ExplainedVarNew: 0.996
# ExplainedVarOld: 0.995
# KL: 0.00145
# PolicyEntropy: -4.94
# PolicyLoss: -0.00154
# Steps: 8.53e+03
# TotalSteps: 2.46e+07
# ValFuncLoss: 0.00066
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :  14.9538   6.4587  27.7926  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0004   0.0001   0.0006   2.0347   0.7443   0.6515
# ***** Episode 89869, Mean R = -24.6  Std R = 7.0  Min R = -39.2
# Beta: 0.0759
# ExplainedVarNew: 0.993
# ExplainedVarOld: 0.991
# KL: 0.000884
# PolicyEntropy: -4.94
# PolicyLoss: -0.00168
# Steps: 8.4e+03
# TotalSteps: 2.46e+07
# ValFuncLoss: 0.00114
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :  19.3642   6.0703  30.7960  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0010   0.0006   0.0022   2.0347   0.7443   0.6515
# Update Cnt = 2900    ET =    296.0   Stats:  Mean, Std, Min, Max
# r_f      |     0.8     0.1    -0.1 |     1.3     0.8     0.1 |    -4.0    -1.5    -0.3 |     3.6     3.9    -0.0
# v_f      |   -1.33   -0.21   -3.92 |    1.14    1.27    0.65 |   -3.65   -3.51   -5.95 |    1.81    2.42   -2.52
# vr_f     |     2.7 |     2.8 |     0.8 |    27.7
# r_i      |   949.8    48.2  2351.7 |   570.3   570.5    28.9 |     5.1  -986.9  2301.6 |  1998.8   991.0  2399.3
# v_i      |  -39.60    1.29  -79.64 |   17.28   18.27    5.65 |  -69.55  -29.40  -89.93 |  -10.16   29.93  -70.02
# norm_rf  |     1.5 |     0.9 |     0.1 |     5.0
# norm_vf  |    4.49 |    0.56 |    2.94 |    6.25
# thrust   |    1293     -41    9411 |    2498    2580    1851 |   -9444  -13683     486 |   14752   13871   14999
# norm_thrust |   10037 |    2410 |    2468 |   15000
# fuel     |     270 |      12 |     240 |     309
# rewards  |  -23.93 |    6.93 |  -47.40 |  -10.57
# fuel_rewards |   -9.27 |    0.42 |  -10.59 |   -8.24
# glideslope_rewards |    0.00 |    0.00 |    0.00 |    0.00
# glideslope_penalty |    0.00 |    0.00 |    0.00 |    0.00
# glideslope |    1.60 |    0.66 |    0.79 |    7.73
# sc_rewards |    0.00 |    0.00 |    0.00 |    0.00
# sc_penalty |    0.00 |    0.00 |    0.00 |    0.00
# sc_margin |  100.00 |    0.00 |  100.00 |  100.00
# range_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_rewards |    0.00 |    0.00 |    0.00 |    0.00
# landing_margin |    2.49 |    0.56 |    0.94 |    4.25
# tracking_rewards |  -14.66 |    6.77 |  -37.43 |   -1.74
# steps    |     277 |      17 |     233 |     319
# ***** Episode 89900, Mean R = -24.5  Std R = 6.9  Min R = -36.6
# Beta: 0.0759
# ExplainedVarNew: 0.996
# ExplainedVarOld: 0.995
# KL: 0.000849
# PolicyEntropy: -4.94
# PolicyLoss: -0.00241
# Steps: 8.6e+03
# TotalSteps: 2.46e+07
# ValFuncLoss: 0.00104
# Variance: 0.0581
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :  10.9677   3.6369  17.2750  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0013   0.0007   0.0026   2.0347   0.7443   0.6515
# ***** Episode 89931, Mean R = -23.8  Std R = 6.1  Min R = -35.6
# Beta: 0.0759
# ExplainedVarNew: 0.994
# ExplainedVarOld: 0.993
# KL: 0.000954
# PolicyEntropy: -4.94
# PolicyLoss: -0.00232
# Steps: 8.58e+03
# TotalSteps: 2.46e+07
# ValFuncLoss: 0.000656
# Variance: 0.0581
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :  10.2928   4.7646  22.7492  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0009   0.0005   0.0021   2.0347   0.7443   0.6515
# ***** Episode 89962, Mean R = -22.0  Std R = 6.3  Min R = -37.1
# Beta: 0.0759
# ExplainedVarNew: 0.992
# ExplainedVarOld: 0.992
# KL: 0.000843
# PolicyEntropy: -4.94
# PolicyLoss: -0.00238
# Steps: 8.58e+03
# TotalSteps: 2.46e+07
# ValFuncLoss: 0.000707
# Variance: 0.058
# lr_multiplier: 0.0878
#
#
# Policy  Gradients: u/sd/Max/C Max/Max u/Max sd :   7.0421   2.4717  14.5020  77.2044  61.9043  20.5143
# ValFun  Gradients: u/sd/Max/C Max/Max u/Max sd :   0.0007   0.0004   0.0015   2.0347   0.7443   0.6515
# ***** Episode 89993, Mean R = -22.3  Std R = 8.3  Min R = -44.6
# Beta: 0.0759
# ExplainedVarNew: 0.996
# ExplainedVarOld: 0.994
# KL: 0.000873
# PolicyEntropy: -4.95
# PolicyLoss: -0.0024
# Steps: 8.63e+03
# TotalSteps: 2.46e+07
# ValFuncLoss: 0.000771
# Variance: 0.0581
# lr_multiplier: 0.0878

# %%
fname = "recurrent_policy-60step"
policy.save_params(fname)
value_function.save_params(fname)
np.save(fname + "_history",env.rl_stats.history)

# %% [markdown]
# # Test Policy

# %%
policy.test_mode=True
env.lander.apf_tau1=300
env.test_policy_batch(agent,1000,print_every=10)
# Out:
# i :  10
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9852.61 |2052.32 |3464.10 |15000.00 |     1
# glideslope | 2.793 | 1.813 | 1.073 |10.931 |     4
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   4.333 |   0.514 |   3.339 |   4.989
# norm_rf  |     1.2 |     0.6 |     0.5 |     2.2
# position |     0.3     0.2    -0.1 |     1.1     0.5     0.0 |    -2.0    -0.6    -0.2 |     2.0     1.0    -0.0
# velocity |  -1.077  -0.507  -3.901 |   1.046   0.949   0.637 |  -2.392  -1.877  -4.766 |   0.994   1.073  -2.681
# fuel     |263.44 |  9.17 |245.50 |280.51
# glideslope |  3.04 |  2.60 |  1.22 | 10.93
# i :  20
# Cumulative Stats (mean,std,max,argmax)
# thrust   |10044.78 |2288.60 |3464.10 |15000.00 |     1
# glideslope | 2.469 | 1.499 | 1.073 |10.931 |     4
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   4.397 |   0.540 |   3.339 |   5.413
# norm_rf  |     1.3 |     0.5 |     0.5 |     2.4
# position |     0.5    -0.0    -0.1 |     1.1     0.6     0.1 |    -2.0    -1.0    -0.2 |     2.3     1.0    -0.0
# velocity |  -1.059  -0.033  -3.881 |   1.135   1.317   0.645 |  -2.723  -2.232  -5.024 |   0.994   2.119  -2.681
# fuel     |267.33 | 10.94 |245.50 |286.62
# glideslope |  2.60 |  2.05 |  1.12 | 10.93
# i :  30
# Cumulative Stats (mean,std,max,argmax)
# thrust   |10020.05 |2233.05 |3464.10 |15000.00 |    21
# glideslope | 2.389 | 1.351 | 1.073 |10.931 |     4
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   4.421 |   0.511 |   3.339 |   5.523
# norm_rf  |     1.2 |     0.6 |     0.3 |     2.4
# position |     0.6    -0.1    -0.1 |     1.1     0.6     0.1 |    -2.0    -1.5    -0.2 |     2.3     1.0    -0.0
# velocity |  -1.142  -0.218  -3.890 |   1.103   1.329   0.587 |  -2.723  -2.232  -5.066 |   0.994   2.119  -2.681
# fuel     |267.79 | 11.12 |245.50 |286.62
# glideslope |  2.45 |  1.77 |  1.12 | 10.93
# i :  40
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9935.77 |2239.95 |3464.10 |15000.00 |    21
# glideslope | 2.189 | 1.260 | 0.937 |10.931 |     4
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   4.395 |   0.495 |   3.339 |   5.523
# norm_rf  |     1.2 |     0.6 |     0.3 |     2.4
# position |     0.7    -0.0    -0.1 |     1.0     0.6     0.1 |    -2.0    -1.5    -0.2 |     2.3     1.4    -0.0
# velocity |  -1.381  -0.159  -3.792 |   1.127   1.285   0.573 |  -3.402  -2.232  -5.066 |   0.994   2.119  -2.681
# fuel     |268.92 | 11.26 |245.50 |292.97
# glideslope |  2.25 |  1.63 |  1.01 | 10.93
# i :  50
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9929.43 |2265.86 |3464.10 |15000.00 |    21
# glideslope | 2.162 | 1.203 | 0.937 |10.931 |     4
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   4.393 |   0.508 |   3.339 |   5.524
# norm_rf  |     1.2 |     0.6 |     0.2 |     2.4
# position |     0.5    -0.0    -0.1 |     1.1     0.6     0.1 |    -2.0    -1.5    -0.2 |     2.3     1.4    -0.0
# velocity |  -1.327  -0.123  -3.794 |   1.180   1.268   0.619 |  -3.402  -2.232  -5.352 |   1.091   2.119  -2.681
# fuel     |268.64 | 10.93 |245.50 |292.97
# glideslope |  2.20 |  1.51 |  1.01 | 10.93
# i :  60
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9908.48 |2268.66 |3464.10 |15000.00 |    21
# glideslope | 2.183 | 1.212 | 0.937 |10.931 |     4
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   4.346 |   0.502 |   3.339 |   5.524
# norm_rf  |     1.1 |     0.6 |     0.2 |     2.4
# position |     0.5    -0.0    -0.1 |     1.0     0.6     0.1 |    -2.0    -1.5    -0.2 |     2.3     1.4    -0.0
# velocity |  -1.337  -0.185  -3.761 |   1.126   1.233   0.617 |  -3.402  -2.232  -5.352 |   1.091   2.119  -2.681
# fuel     |268.15 | 10.63 |245.50 |292.97
# glideslope |  2.21 |  1.46 |  1.01 | 10.93
# i :  70
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9874.68 |2289.43 |3464.10 |15000.00 |    21
# glideslope | 2.132 | 1.162 | 0.937 |10.931 |     4
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   4.307 |   0.489 |   3.339 |   5.524
# norm_rf  |     1.1 |     0.6 |     0.2 |     2.4
# position |     0.5    -0.0    -0.1 |     1.0     0.6     0.1 |    -2.0    -1.5    -0.2 |     2.3     1.4    -0.0
# velocity |  -1.379  -0.182  -3.704 |   1.113   1.241   0.594 |  -3.402  -2.313  -5.352 |   1.091   2.119  -2.681
# fuel     |268.28 | 11.08 |243.38 |292.97
# glideslope |  2.14 |  1.38 |  1.01 | 10.93
# i :  80
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9857.19 |2292.56 |3464.10 |15000.00 |    21
# glideslope | 2.157 | 1.562 | 0.937 |89.315 |    76
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   4.289 |   0.467 |   3.339 |   5.524
# norm_rf  |     1.1 |     0.6 |     0.2 |     2.5
# position |     0.5     0.0    -0.1 |     1.0     0.5     0.1 |    -2.0    -1.5    -0.2 |     2.5     1.4    -0.0
# velocity |  -1.394  -0.151  -3.679 |   1.107   1.239   0.591 |  -3.402  -2.313  -5.352 |   1.091   2.119  -2.681
# fuel     |268.18 | 10.61 |243.38 |292.97
# glideslope |  2.14 |  1.40 |  0.99 | 10.93
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-1601cd532165> in <module>()
#       1 policy.test_mode=True
#       2 env.lander.apf_tau1=300
# ----> 3 env.test_policy_batch(agent,1000,print_every=10)
#
# ~/Study/Subjects/MachineLearning/Projects/RL_Meta-Learning-master/Mars3dof_env/env.py in test_policy_batch(self, agent, n, print_every, use_ts)
#     144         self.display_errors = True
#     145         for i in range(n):
# --> 146             agent.run_episode()
#     147             #self.test_policy_episode(policy, input_normalizer,use_ts=use_ts)
#     148             if i % print_every == 0 and i > 0:
#
# ~/Study/Subjects/MachineLearning/Projects/RL_Meta-Learning-master/RL_lib/Agents/PPO/agent.py in run_episode(self)
#      52
#      53     def run_episode(self):
# ---> 54         traj = self.arch.run_episode(self.env, self.policy, self.val_func, self.model, self.recurrent_steps, self.use_timestep)
#      55         padded_traj = {}
#      56         for k,v in traj.items():
#
# ~/Study/Subjects/MachineLearning/Projects/RL_Meta-Learning-master/RL_lib/Agents/PPO/arch_policy_gtvf.py in run_episode(self, env, policy, val_func, model, recurrent_steps, use_timestep, add_padding)
#      39             vpreds.append(vpred)
#      40
# ---> 41             obs, reward, done, reward_info = env.step(env_action)
#      42             nobserves.append(obs.astype(np.float64).reshape((1, -1)))
#      43             gt_obs = self.gt_func(0.0).astype(np.float64).reshape((1, -1))
#
# ~/Study/Subjects/MachineLearning/Projects/RL_Meta-Learning-master/Mars3dof_env/env.py in step(self, action)
#      94         action = envu.limit_thrust(action, self.lander.min_thrust, self.lander.max_thrust)
#      95         # update using current state and action so we capture IC
# ---> 96         self.lander.update_trajectory(False, self.t, action)
#      97
#      98         steps_to_sim = int(np.round(self.nav_period / self.dynamics.h))
#
# ~/Study/Subjects/MachineLearning/Projects/RL_Meta-Learning-master/Mars3dof_env/lander_model.py in update_trajectory(self, done, t, action)
#      50     def update_trajectory(self, done, t, action):
#      51
# ---> 52         es = self.get_landing_state(t)
#      53         for k,v in es.items():
#      54             self.trajectory[k].append(v)
#
# ~/Study/Subjects/MachineLearning/Projects/RL_Meta-Learning-master/Mars3dof_env/lander_model.py in get_landing_state(self, t)
#     246         landing_state['los'] = self.state['position'] / np.linalg.norm(self.state['position'])
#     247         landing_state['dlos'] = envu.get_dlos(self.state['position'], self.state['velocity'])
# --> 248         landing_state['zem'] = envu.get_zem(self.state['position'], self.state['velocity'])
#     249         landing_state['t_go'] = self.state['t_go']
#     250         return landing_state
#
# ~/Study/Subjects/MachineLearning/Projects/RL_Meta-Learning-master/Mars3dof_env/env_utils.py in get_zem(r_tm, v_tm)
#     207     range = np.linalg.norm(r_tm)
#     208     if True: #vc > 0.1:
# --> 209         t_go = get_tgo(r_tm, v_tm, 4.0)
#     210         zem = t_go * v_tm + r_tm
#     211         zem = r_tm - t_go * v_tm
#
# ~/Study/Subjects/MachineLearning/Projects/RL_Meta-Learning-master/Mars3dof_env/env_utils.py in get_tgo(rg, vg, g)
#     229         p = [gamma + np.linalg.norm(g)**2/2  ,  0., -2. * np.dot(vg,vg)  , -12. * np.dot(vg,rg) , -18. * np.dot(rg , rg)]
#     230         #print(rg, vg, p)
# --> 231         p_roots = np.roots(p)
#     232         for i in range(len(p_roots)):
#     233             if np.abs(np.imag(p_roots[i])) < 0.0001:
#
# ~/venv/python/lib/python3.5/site-packages/numpy/lib/polynomial.py in roots(p)
#     222         A = diag(NX.ones((N-2,), p.dtype), -1)
#     223         A[0,:] = -p[1:] / p[0]
# --> 224         roots = eigvals(A)
#     225     else:
#     226         roots = NX.array([])
#
# ~/venv/python/lib/python3.5/site-packages/numpy/linalg/linalg.py in eigvals(a)
#     951
#     952
# --> 953 def eigvals(a):
#     954     """
#     955     Compute the eigenvalues of a general matrix.
#
# KeyboardInterrupt:

# %%
len(lander_model.trajectory_list)
traj_list = lander_model.trajectory_list[0:100]
len(traj_list)
np.save('recurrent_policy-rkill-60step_100traj',traj_list)

# %%
env.lander.sensor_pos_bias_range=(-0.05,0.05)
env.lander.sensor_vel_bias_range=(-0.05,0.05)
env.test_policy_batch(agent,10000,print_every=100)
# Out:
# i :  100
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9932.68 |2381.93 |2000.00 |15000.00 |    28
# glideslope | 5.951 |19.713 | 0.552 |1071.393 |    61
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.070 |   1.074 |   1.400
# norm_rf  |     0.3 |     0.2 |     0.1 |     0.9
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.5    -0.4    -0.1 |     0.9     0.4    -0.0
# velocity |   0.027  -0.053  -1.217 |   0.042   0.034   0.070 |  -0.054  -0.136  -1.397 |   0.133   0.016  -1.073
# fuel     |286.89 | 12.85 |261.19 |326.79
# glideslope | 39.98 | 43.45 | 14.03 |326.35
# i :  200
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9851.14 |2359.94 |2000.00 |15000.00 |   145
# glideslope | 5.529 |17.332 | 0.552 |1071.393 |    61
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.217 |   0.069 |   1.056 |   1.400
# norm_rf  |     0.3 |     0.1 |     0.0 |     0.9
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.5    -0.4    -0.1 |     0.9     0.4    -0.0
# velocity |   0.026  -0.054  -1.215 |   0.042   0.036   0.068 |  -0.058  -0.136  -1.397 |   0.133   0.016  -1.052
# fuel     |287.05 | 14.77 |255.93 |335.89
# glideslope | 39.15 | 44.90 | 13.57 |410.06
# i :  300
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9864.68 |2358.65 |2000.00 |15000.00 |   145
# glideslope | 5.776 |18.647 | 0.403 |1071.393 |    61
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.072 |   1.056 |   1.435
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.5    -0.5    -0.1 |     1.7     0.4    -0.0
# velocity |   0.027  -0.052  -1.219 |   0.041   0.036   0.072 |  -0.058  -0.136  -1.432 |   0.133   0.021  -1.052
# fuel     |286.92 | 14.53 |250.88 |335.89
# glideslope | 39.95 | 42.18 | 13.02 |410.06
# i :  400
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9864.83 |2360.56 |2000.00 |15000.00 |   145
# glideslope | 5.758 |18.618 | 0.403 |1071.393 |    61
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.219 |   0.072 |   1.056 |   1.435
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.5    -0.5    -0.1 |     1.7     0.4    -0.0
# velocity |   0.027  -0.052  -1.217 |   0.041   0.037   0.071 |  -0.064  -0.136  -1.432 |   0.133   0.021  -1.052
# fuel     |286.97 | 14.98 |250.88 |335.89
# glideslope | 39.50 | 39.21 | 13.02 |410.06
# i :  500
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9858.14 |2351.77 |2000.00 |15000.00 |   145
# glideslope | 5.839 |21.907 | 0.403 |3702.969 |   481
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.072 |   1.056 |   1.435
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.5    -0.5    -0.1 |     1.7     0.5    -0.0
# velocity |   0.025  -0.052  -1.217 |   0.041   0.037   0.071 |  -0.064  -0.136  -1.432 |   0.133   0.021  -1.052
# fuel     |287.43 | 14.97 |250.88 |335.89
# glideslope | 40.25 | 40.83 | 12.66 |410.06
# i :  600
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9848.27 |2360.33 |2000.00 |15000.00 |   145
# glideslope | 5.819 |21.532 | 0.403 |3702.969 |   481
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.073 |   1.051 |   1.435
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.5    -0.1 |     1.7     0.5    -0.0
# velocity |   0.024  -0.053  -1.217 |   0.041   0.037   0.072 |  -0.075  -0.136  -1.432 |   0.133   0.021  -1.051
# fuel     |287.65 | 15.05 |250.88 |339.61
# glideslope | 39.74 | 38.92 | 12.66 |410.06
# i :  700
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9862.24 |2356.38 |2000.00 |15000.00 |   145
# glideslope | 5.851 |21.852 | 0.403 |3702.969 |   481
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.071 |   1.051 |   1.435
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.5    -0.1 |     1.7     0.5    -0.0
# velocity |   0.024  -0.053  -1.218 |   0.041   0.037   0.071 |  -0.075  -0.136  -1.432 |   0.133   0.021  -1.051
# fuel     |287.52 | 14.88 |250.88 |339.61
# glideslope | 39.71 | 41.74 | 12.66 |536.97
# i :  800
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9860.53 |2359.33 |2000.00 |15000.00 |   145
# glideslope | 5.799 |21.833 | 0.403 |3702.969 |   481
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.071 |   1.051 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.5    -0.1 |     1.7     0.5    -0.0
# velocity |   0.024  -0.054  -1.218 |   0.041   0.037   0.071 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.051
# fuel     |287.80 | 15.23 |250.86 |339.61
# glideslope | 39.75 | 46.12 | 12.66 |677.97
# i :  900
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9858.45 |2359.43 |2000.00 |15000.00 |   145
# glideslope | 5.806 |21.544 | 0.403 |3702.969 |   481
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.072 |   1.046 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.5    -0.1 |     1.7     0.5    -0.0
# velocity |   0.025  -0.054  -1.217 |   0.042   0.037   0.071 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.045
# fuel     |287.49 | 15.18 |250.86 |339.61
# glideslope | 40.21 | 52.76 | 12.66 |809.47
# i :  1000
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9853.95 |2356.79 |2000.00 |15000.00 |   145
# glideslope | 5.840 |21.501 | 0.403 |3702.969 |   481
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.219 |   0.071 |   1.046 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.5    -0.1 |     1.7     0.5    -0.0
# velocity |   0.025  -0.053  -1.216 |   0.042   0.037   0.070 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.045
# fuel     |287.18 | 15.10 |250.86 |339.61
# glideslope | 39.73 | 50.70 | 12.66 |809.47
# i :  1100
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9864.21 |2358.55 |2000.00 |15000.00 |   145
# glideslope | 5.896 |21.424 | 0.403 |3702.969 |   481
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.071 |   1.046 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.5    -0.1 |     1.7     0.5    -0.0
# velocity |   0.025  -0.053  -1.218 |   0.042   0.037   0.071 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.045
# fuel     |287.20 | 15.17 |250.86 |339.61
# glideslope | 39.75 | 49.38 | 12.66 |809.47
# i :  1200
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9860.36 |2358.50 |2000.00 |15000.00 |   145
# glideslope | 5.926 |21.222 | 0.403 |3702.969 |   481
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.072 |   1.046 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.5    -0.1 |     1.7     0.5    -0.0
# velocity |   0.025  -0.053  -1.218 |   0.042   0.037   0.071 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.045
# fuel     |287.18 | 15.03 |250.86 |339.61
# glideslope | 39.61 | 48.22 | 12.66 |809.47
# i :  1300
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9856.79 |2357.14 |2000.00 |15000.00 |   145
# glideslope | 5.952 |21.361 | 0.403 |3702.969 |   481
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.072 |   1.046 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.5    -0.0
# velocity |   0.025  -0.054  -1.217 |   0.042   0.038   0.072 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.045
# fuel     |287.01 | 15.10 |250.86 |339.61
# glideslope | 39.60 | 47.82 | 12.66 |809.47
# i :  1400
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9862.38 |2354.62 |2000.00 |15000.00 |   145
# glideslope | 5.921 |21.277 | 0.403 |3702.969 |   481
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.072 |   1.042 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.5    -0.0
# velocity |   0.025  -0.054  -1.218 |   0.042   0.038   0.072 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.041
# fuel     |286.94 | 15.05 |250.86 |339.61
# glideslope | 39.17 | 46.61 | 12.66 |809.47
# i :  1500
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9858.78 |2353.55 |2000.00 |15000.00 |   145
# glideslope | 5.964 |22.088 | 0.403 |3702.969 |   481
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.073 |   1.042 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.5    -0.0
# velocity |   0.025  -0.054  -1.217 |   0.042   0.037   0.072 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.041
# fuel     |286.83 | 15.05 |250.86 |339.61
# glideslope | 39.37 | 46.45 | 12.66 |809.47
# i :  1600
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9858.01 |2356.43 |2000.00 |15000.00 |   145
# glideslope | 5.977 |24.975 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.219 |   0.072 |   1.042 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.025  -0.054  -1.217 |   0.042   0.037   0.072 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.041
# fuel     |286.80 | 15.02 |250.86 |339.61
# glideslope | 40.20 | 54.90 | 12.66 |1219.08
# i :  1700
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9862.74 |2357.02 |2000.00 |15000.00 |   145
# glideslope | 5.963 |24.537 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.219 |   0.072 |   1.042 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.025  -0.053  -1.216 |   0.042   0.038   0.072 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.041
# fuel     |286.82 | 14.98 |250.86 |339.61
# glideslope | 39.96 | 54.08 | 12.66 |1219.08
# i :  1800
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9864.98 |2355.29 |2000.00 |15000.00 |   145
# glideslope | 5.955 |24.424 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.219 |   0.072 |   1.042 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.025  -0.054  -1.216 |   0.042   0.038   0.071 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.041
# fuel     |286.80 | 14.92 |250.86 |339.61
# glideslope | 40.46 | 61.44 | 12.66 |1322.71
# i :  1900
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9867.79 |2354.59 |2000.00 |15000.00 |   145
# glideslope | 5.951 |24.121 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.219 |   0.072 |   1.042 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.053  -1.217 |   0.042   0.037   0.072 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.041
# fuel     |286.69 | 14.82 |250.86 |339.61
# glideslope | 40.39 | 60.80 | 12.66 |1322.71
# i :  2000
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9870.20 |2354.98 |2000.00 |15000.00 |   145
# glideslope | 5.937 |23.986 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.072 |   1.042 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.217 |   0.042   0.037   0.072 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.041
# fuel     |286.62 | 14.84 |250.86 |339.61
# glideslope | 40.18 | 59.75 | 12.66 |1322.71
# i :  2100
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9868.74 |2354.72 |2000.00 |15000.00 |   145
# glideslope | 5.914 |23.696 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.072 |   1.042 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.217 |   0.042   0.037   0.072 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.041
# fuel     |286.63 | 14.85 |250.86 |339.61
# glideslope | 39.97 | 58.65 | 12.66 |1322.71
# i :  2200
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9869.39 |2355.79 |2000.00 |15000.00 |   145
# glideslope | 5.933 |23.603 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.073 |   1.042 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.217 |   0.042   0.038   0.072 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.041
# fuel     |286.57 | 14.86 |250.86 |339.61
# glideslope | 39.91 | 57.74 | 12.64 |1322.71
# i :  2300
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9874.28 |2355.83 |2000.00 |15000.00 |   145
# glideslope | 5.933 |23.329 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.073 |   1.042 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.072 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.041
# fuel     |286.73 | 15.02 |250.86 |339.61
# glideslope | 39.73 | 56.88 | 12.64 |1322.71
# i :  2400
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9869.56 |2354.63 |2000.00 |15000.00 |   145
# glideslope | 5.906 |23.217 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.073 |   1.042 |   1.490
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.072 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.041
# fuel     |286.77 | 15.09 |250.86 |339.61
# glideslope | 39.75 | 57.18 | 12.64 |1322.71
# i :  2500
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9872.76 |2356.07 |2000.00 |15000.00 |   145
# glideslope | 5.907 |22.998 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.037   0.073 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.039
# fuel     |286.60 | 15.05 |250.86 |339.61
# glideslope | 39.68 | 56.57 | 12.64 |1322.71
# i :  2600
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9874.31 |2356.76 |2000.00 |15000.00 |   145
# glideslope | 5.895 |22.833 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.6    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.075  -0.136  -1.490 |   0.133   0.027  -1.039
# fuel     |286.61 | 15.03 |250.86 |339.61
# glideslope | 39.65 | 56.38 | 12.64 |1322.71
# i :  2700
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9873.50 |2355.14 |2000.00 |15000.00 |   145
# glideslope | 5.895 |23.430 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.133   0.027  -1.039
# fuel     |286.57 | 14.99 |250.86 |339.61
# glideslope | 39.80 | 57.75 | 12.64 |1322.71
# i :  2800
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9872.21 |2354.27 |2000.00 |15000.00 |   145
# glideslope | 5.901 |23.501 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.025  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.133   0.027  -1.039
# fuel     |286.66 | 15.08 |250.86 |341.23
# glideslope | 39.98 | 57.24 | 12.64 |1322.71
# i :  2900
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9873.65 |2353.50 |2000.00 |15000.00 |   145
# glideslope | 5.894 |23.339 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.025  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.133   0.027  -1.039
# fuel     |286.61 | 15.11 |250.86 |341.23
# glideslope | 40.16 | 57.99 | 12.64 |1322.71
# i :  3000
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9868.93 |2353.66 |2000.00 |15000.00 |   145
# glideslope | 5.891 |23.168 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.025  -0.054  -1.217 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.133   0.027  -1.039
# fuel     |286.65 | 15.10 |250.86 |341.23
# glideslope | 40.33 | 58.68 | 12.64 |1322.71
# i :  3100
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9869.75 |2354.14 |2000.00 |15000.00 |   145
# glideslope | 5.886 |23.114 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.220 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.025  -0.054  -1.217 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.133   0.027  -1.039
# fuel     |286.72 | 15.14 |250.86 |341.23
# glideslope | 40.24 | 58.03 | 12.64 |1322.71
# i :  3200
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9871.64 |2355.36 |2000.00 |15000.00 |   145
# glideslope | 5.864 |22.996 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1    -0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.025  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.133   0.027  -1.039
# fuel     |286.82 | 15.17 |250.86 |345.33
# glideslope | 40.27 | 57.65 | 12.64 |1322.71
# i :  3300
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9872.94 |2355.60 |2000.00 |15000.00 |   145
# glideslope | 5.867 |22.995 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.074 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.133   0.027  -1.039
# fuel     |286.78 | 15.22 |250.86 |345.33
# glideslope | 40.49 | 59.28 | 12.64 |1322.71
# i :  3400
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9870.24 |2355.54 |2000.00 |15000.00 |   145
# glideslope | 5.870 |22.929 | 0.403 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.135   0.027  -1.039
# fuel     |286.71 | 15.26 |248.55 |345.33
# glideslope | 40.44 | 58.75 | 12.64 |1322.71
# i :  3500
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9871.09 |2355.09 |2000.00 |15000.00 |   145
# glideslope | 5.887 |22.825 | 0.396 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.135   0.028  -1.039
# fuel     |286.70 | 15.31 |248.55 |345.33
# glideslope | 40.30 | 58.06 | 12.64 |1322.71
# i :  3600
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9871.07 |2355.51 |2000.00 |15000.00 |   145
# glideslope | 5.889 |23.114 | 0.396 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.6    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.135   0.028  -1.039
# fuel     |286.72 | 15.32 |248.55 |345.33
# glideslope | 40.37 | 57.84 | 12.64 |1322.71
# i :  3700
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9870.64 |2355.55 |2000.00 |15000.00 |   145
# glideslope | 5.875 |22.938 | 0.396 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.9    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.135   0.028  -1.039
# fuel     |286.73 | 15.33 |248.55 |345.33
# glideslope | 40.12 | 57.22 | 12.64 |1322.71
# i :  3800
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9872.73 |2356.47 |2000.00 |15000.00 |   145
# glideslope | 5.870 |22.818 | 0.396 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.9    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.075  -0.141  -1.490 |   0.135   0.028  -1.039
# fuel     |286.73 | 15.31 |248.55 |345.33
# glideslope | 40.25 | 56.92 | 12.64 |1322.71
# i :  3900
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9871.66 |2355.39 |2000.00 |15000.00 |   145
# glideslope | 5.870 |22.814 | 0.396 |7897.179 |  1514
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.9    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.083  -0.141  -1.490 |   0.135   0.028  -1.039
# fuel     |286.70 | 15.28 |248.55 |345.33
# glideslope | 40.33 | 56.82 | 12.11 |1322.71
# i :  4000
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9870.03 |2355.32 |2000.00 |15000.00 |   145
# glideslope | 5.879 |25.110 | 0.396 |11579.283 |  3914
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.041 |   1.491
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.9    -0.0
# velocity |   0.025  -0.053  -1.218 |   0.042   0.038   0.073 |  -0.083  -0.141  -1.490 |   0.135   0.028  -1.039
# fuel     |286.73 | 15.31 |248.55 |345.33
# glideslope | 40.45 | 57.63 | 12.11 |1322.71
# i :  4100
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9867.98 |2355.25 |2000.00 |15000.00 |   145
# glideslope | 5.877 |24.983 | 0.396 |11579.283 |  3914
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.040 |   1.506
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.9    -0.0
# velocity |   0.025  -0.053  -1.218 |   0.042   0.038   0.073 |  -0.083  -0.141  -1.501 |   0.135   0.028  -1.039
# fuel     |286.70 | 15.32 |246.23 |345.33
# glideslope | 40.65 | 58.47 | 12.11 |1322.71
# i :  4200
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9870.10 |2355.56 |2000.00 |15000.00 |   145
# glideslope | 5.874 |24.882 | 0.396 |11579.283 |  3914
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.040 |   1.506
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.9    -0.0
# velocity |   0.025  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.083  -0.141  -1.501 |   0.135   0.028  -1.039
# fuel     |286.69 | 15.35 |246.23 |345.33
# glideslope | 40.43 | 57.91 | 12.11 |1322.71
# i :  4300
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9868.31 |2355.34 |2000.00 |15000.00 |   145
# glideslope | 5.862 |24.731 | 0.396 |11579.283 |  3914
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.040 |   1.506
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.9    -0.0
# velocity |   0.026  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.083  -0.141  -1.501 |   0.135   0.028  -1.039
# fuel     |286.70 | 15.33 |246.23 |345.33
# glideslope | 40.41 | 57.70 | 12.11 |1322.71
# i :  4400
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9868.27 |2356.24 |2000.00 |15000.00 |   145
# glideslope | 5.865 |24.661 | 0.396 |11579.283 |  3914
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.040 |   1.506
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.9    -0.0
# velocity |   0.025  -0.054  -1.218 |   0.042   0.038   0.073 |  -0.083  -0.141  -1.501 |   0.135   0.028  -1.039
# fuel     |286.69 | 15.37 |246.23 |345.33
# glideslope | 40.44 | 57.46 | 12.11 |1322.71
# i :  4500
# Cumulative Stats (mean,std,max,argmax)
# thrust   |9868.25 |2356.10 |2000.00 |15000.00 |   145
# glideslope | 5.861 |24.582 | 0.396 |11579.283 |  3914
# sc_margin |100.000 | 0.000 |100.000 |100.000 |     0
#
# Final Stats (mean,std,min,max)
# norm_vf  |   1.221 |   0.073 |   1.040 |   1.506
# norm_rf  |     0.3 |     0.2 |     0.0 |     1.7
# position |     0.1     0.0    -0.0 |     0.3     0.2     0.0 |    -0.7    -0.6    -0.1 |     1.7     0.9    -0.0
# velocity |   0.026  -0.053  -1.218 |   0.042   0.038   0.073 |  -0.083  -0.141  -1.501 |   0.135   0.028  -1.039
# fuel     |286.65 | 15.39 |246.23 |345.33
# glideslope | 40.59 | 57.57 | 12.11 |1322.71
